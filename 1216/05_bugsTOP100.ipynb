# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2020-12-16 19:08:42.932152

# %%
from datetime import datetime
now = datetime.now()
print(now)
# Out:
# 2020-12-16 19:09:33.170152

# %%
from datetime import datetime as dt
now = dt.now()
print(now)
# Out:
# 2020-12-16 19:10:01.693487

# %%
print(dt.now()) # 컴퓨터 시스템의 날짜와 시간을 얻어온다.
print(dt.now().year)
print(dt.now().month)
print(dt.now().day)
print(dt.now().hour)
print(dt.now().minute)
print(dt.now().second)
print(dt.now().microsecond)
print(dt.now().microsecond // 1000) # 밀리초
print(dt.now().weekday()) # 요일을 숫자로 리턴한다. 월(0), 화(1), ..., 금(4), 토(5), 일(6)
week = ['월', '화', '수', '목', '금', '토', '일']
print(week[dt.now().weekday()] + '요일')
# Out:
# 2020-12-16 19:17:09.413892
# 2020
# 12
# 16
# 19
# 17
# 9
# 414892
# 414
# 2
# 수요일

# %%
targetSite = 'https://music.bugs.co.kr/chart'

# %%
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))

for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# What Do I Call You
# 불면증 (Vocal by 윤하)
# For You (Feat. Crush)
# Playlist
# To the moon
# 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 들불 (Wildfire)
# Galaxy
# All I Want for Christmas Is You
# Lovegame
# Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
# Life Goes On
# Dynamite
# Santa Tell Me
# 지켜줄게 (바니와 오빠들 X 노을)
# Hate you
# Panorama
# 한잔이면 지워질까
# 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
# Black Mamba
# 잠이 오질 않네요
# 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
# Lovesick Girls
# 밤하늘의 별을(2020)
# 미리 메리 크리스마스 (feat. 천둥 Of MBLAQ)
# 취기를 빌려 (취향저격 그녀 X 산들)
# I CAN’T STOP ME
# 잘할게
# Snowman
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 사라진 모든 것들에게(with ELLE KOREA)
# 달링 (Darling)
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 적외선 카메라
# 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
# Better
# 가을밤에 든 생각
# I am not your ocean anymore
# 크리스마스니까
# MAGO
# 어김없이 이 거리에
# 딩가딩가 (Dingga)
# 혼술하고 싶은 밤
# 0415
# Freak (Prod. Slom)
# 한 번에 알아본 사랑 (바른연애 길잡이 X 양요섭)
# Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
# HAPPENING
# 힘든 건 사랑이 아니다
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# Dolphin
# 34+35
# When We Disco (Duet with 선미)
# SO BAD
# 내 방을 여행하는 법
# 에잇(Prod.&Feat. SUGA of BTS)
# 부어라 비워라 (Tricker) (Prod. GroovyRoom)
# 너도 아는
# 니 눈이 보여 (Feat. 동하)
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# You’re so lonely now, so you need me back by your side again
# 이제 나만 믿어요
# 오래된 노래
# 90's Love
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 뻔한남자
# 늦은 밤 너의 집 앞 골목길에서
# Blue & Grey
# DON'T TOUCH ME
# Bad News Cypher vol.2 (Feat. TakeOne)
# Blueming
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# Memories
# Hall&Oates
# How You Like That
# iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
# Bad Boy
# 잠시
# 모든 날, 모든 순간 (Every day, Every Moment)
# 홀로
# Loveless
# 마음을 드려요
# Square (2017)
# Text Me Merry Christmas (feat. Kristen Bell)
# 어떻게 지내 (Prod. By VAN.C)
# METEOR
# I'm Cold
# Dancing Cartoon
# 주저하는 연인들을 위해
# 평행선 (Light and Darkness)
# Ms. Delicate
# 세상에 나쁜 개는 없다 (Feat. YDG, Zion.T) (Prod. Slom)
# 마리아 (Maria)
# I’ll be your family!
# 밤새 (취향저격 그녀 X 카더가든)
# 밤편지
# Must Have Love (우리들의 겨울)
# 아로하
# Pretty Savage

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))

for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[1])
    print(artist.text.strip().split('\n')[0])
# Out:
# 태연 (TAEYEON)
# 에피톤 프로젝트(Epitone Project)
# 이하이
# 태연 (TAEYEON)
# 태연 (TAEYEON)
# 스윙스(Swings)
# 미란이
# 태연 (TAEYEON)
# 태연 (TAEYEON)
# Mariah Carey(머라이어 캐리)
# 백예린 (Yerin Baek)
# 미란이
# 방탄소년단
# 방탄소년단
# Ariana Grande(아리아나 그란데)
# 노을
# 백예린 (Yerin Baek)
# IZ*ONE(아이즈원)
# 황인욱
# 릴보이(lIlBOI)
# aespa
# 장범준
# 머쉬베놈(MUSHVENOM)
# BLACKPINK
# 경서
# 아이유(IU)
# 산들
# TWICE (트와이스)
# 이승기
# Sia(시아)
# 적재
# 코드 쿤스트
# 영준 [Brown Eyed Soul]
# Jawsh 685
# 원슈타인
# KHUNDI PANDA
# 보아 (BoA)
# 잔나비
# 백예린 (Yerin Baek)
# 성시경
# 여자친구(GFRIEND)
# 정승환
# 마마무(Mamamoo)
# 벤
# 백예린 (Yerin Baek)
# 릴보이(lIlBOI)
# 양요섭
# KHUNDI PANDA
# AKMU (악동뮤지션)
# 임창정
# 규현 (KYUHYUN)
# 오마이걸(OH MY GIRL)
# Ariana Grande(아리아나 그란데)
# 박진영
# STAYC(스테이씨)
# 방탄소년단
# 아이유(IU)
# 머쉬베놈(MUSHVENOM)
# 폴킴(Paul Kim)
# 015B
# 장범준
# 백예린 (Yerin Baek)
# 임영웅
# 스탠딩 에그(Standing Egg)
# NCT U
# AKMU (악동뮤지션)
# 이승기
# 노을
# 방탄소년단
# 환불원정대
# 릴보이(lIlBOI)
# 아이유(IU)
# 방탄소년단
# Maroon 5(마룬 파이브)
# 백예린 (Yerin Baek)
# BLACKPINK
# 래원 (Layone)
# 청하
# 방탄소년단
# 폴킴(Paul Kim)
# 이하이
# 백예린 (Yerin Baek)
# 아이유(IU)
# 백예린 (Yerin Baek)
# Straight No Chaser(스트레이트 노 체이서)
# 오반 (OVAN)
# 창모(CHANGMO)
# 김성규
# 볼빨간사춘기
# 잔나비
# 권진아
# 백예린 (Yerin Baek)
# 원슈타인
# 화사(Hwa Sa)
# 백예린 (Yerin Baek)
# 카더가든
# 아이유(IU)
# SG워너비
# 조정석
# BLACKPINK

# %%
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2020-12-16 20:03:53.739832
#   1위 태연 (TAEYEON) - What Do I Call You
#   2위 에피톤 프로젝트(Epitone Project) - 불면증 (Vocal by 윤하)
#   3위 이하이 - For You (Feat. Crush)
#   4위 태연 (TAEYEON) - Playlist
#   5위 태연 (TAEYEON) - To the moon
#   6위 스윙스(Swings) - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#   7위 미란이 - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   8위 태연 (TAEYEON) - 들불 (Wildfire)
#   9위 태연 (TAEYEON) - Galaxy
#  10위 Mariah Carey(머라이어 캐리) - All I Want for Christmas Is You
#  11위 백예린 (Yerin Baek) - Lovegame
#  12위 미란이 - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  13위 방탄소년단 - Life Goes On
#  14위 방탄소년단 - Dynamite
#  15위 Ariana Grande(아리아나 그란데) - Santa Tell Me
#  16위 노을 - 지켜줄게 (바니와 오빠들 X 노을)
#  17위 백예린 (Yerin Baek) - Hate you
#  18위 IZ*ONE(아이즈원) - Panorama
#  19위 황인욱 - 한잔이면 지워질까
#  20위 릴보이(lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#  21위 aespa - Black Mamba
#  22위 장범준 - 잠이 오질 않네요
#  23위 머쉬베놈(MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  24위 BLACKPINK - Lovesick Girls
#  25위 경서 - 밤하늘의 별을(2020)
#  26위 아이유(IU) - 미리 메리 크리스마스 (feat. 천둥 Of MBLAQ)
#  27위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  28위 TWICE (트와이스) - I CAN’T STOP ME
#  29위 이승기 - 잘할게
#  30위 Sia(시아) - Snowman
#  31위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  32위 코드 쿤스트 - 사라진 모든 것들에게(with ELLE KOREA)
#  33위 영준 [Brown Eyed Soul] - 달링 (Darling)
#  34위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  35위 원슈타인 - 적외선 카메라
#  36위 KHUNDI PANDA - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  37위 보아 (BoA) - Better
#  38위 잔나비 - 가을밤에 든 생각
#  39위 백예린 (Yerin Baek) - I am not your ocean anymore
#  40위 성시경 - 크리스마스니까
#  41위 여자친구(GFRIEND) - MAGO
#  42위 정승환 - 어김없이 이 거리에
#  43위 마마무(Mamamoo) - 딩가딩가 (Dingga)
#  44위 벤 - 혼술하고 싶은 밤
#  45위 백예린 (Yerin Baek) - 0415
#  46위 릴보이(lIlBOI) - Freak (Prod. Slom)
#  47위 양요섭 - 한 번에 알아본 사랑 (바른연애 길잡이 X 양요섭)
#  48위 KHUNDI PANDA - Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
#  49위 AKMU (악동뮤지션) - HAPPENING
#  50위 임창정 - 힘든 건 사랑이 아니다
#  51위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  52위 오마이걸(OH MY GIRL) - Dolphin
#  53위 Ariana Grande(아리아나 그란데) - 34+35
#  54위 박진영 - When We Disco (Duet with 선미)
#  55위 STAYC(스테이씨) - SO BAD
#  56위 방탄소년단 - 내 방을 여행하는 법
#  57위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  58위 머쉬베놈(MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. GroovyRoom)
#  59위 폴킴(Paul Kim) - 너도 아는
#  60위 015B - 니 눈이 보여 (Feat. 동하)
#  61위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  62위 백예린 (Yerin Baek) - You’re so lonely now, so you need me back by your side again
#  63위 임영웅 - 이제 나만 믿어요
#  64위 스탠딩 에그(Standing Egg) - 오래된 노래
#  65위 NCT U - 90's Love
#  66위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  67위 이승기 - 뻔한남자
#  68위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  69위 방탄소년단 - Blue & Grey
#  70위 환불원정대 - DON'T TOUCH ME
#  71위 릴보이(lIlBOI) - Bad News Cypher vol.2 (Feat. TakeOne)
#  72위 아이유(IU) - Blueming
#  73위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  74위 Maroon 5(마룬 파이브) - Memories
#  75위 백예린 (Yerin Baek) - Hall&Oates
#  76위 BLACKPINK - How You Like That
#  77위 래원 (Layone) - iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
#  78위 청하 - Bad Boy
#  79위 방탄소년단 - 잠시
#  80위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  81위 이하이 - 홀로
#  82위 백예린 (Yerin Baek) - Loveless
#  83위 아이유(IU) - 마음을 드려요
#  84위 백예린 (Yerin Baek) - Square (2017)
#  85위 Straight No Chaser(스트레이트 노 체이서) - Text Me Merry Christmas (feat. Kristen Bell)
#  86위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  87위 창모(CHANGMO) - METEOR
#  88위 김성규 - I'm Cold
#  89위 볼빨간사춘기 - Dancing Cartoon
#  90위 잔나비 - 주저하는 연인들을 위해
#  91위 권진아 - 평행선 (Light and Darkness)
#  92위 백예린 (Yerin Baek) - Ms. Delicate
#  93위 원슈타인 - 세상에 나쁜 개는 없다 (Feat. YDG, Zion.T) (Prod. Slom)
#  94위 화사(Hwa Sa) - 마리아 (Maria)
#  95위 백예린 (Yerin Baek) - I’ll be your family!
#  96위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
#  97위 아이유(IU) - 밤편지
#  98위 SG워너비 - Must Have Love (우리들의 겨울)
#  99위 조정석 - 아로하
# 100위 BLACKPINK - Pretty Savage

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
# 크롤링한 데이터를 텍스트 파일에 저장하려는 경우 아래와 같이 파일을 열면 한글 인코딩 문제로 인해서 UnicodeEncodeError가
# 발생될 수 있다.
file = open('bugsTOP100.txt', 'w')
# UnicodeEncodeError: 'cp949' codec can't encode character '\xf1' in position 29: illegal multibyte sequence 에러가
# 발생되면 아래와 같이 파일을 open 시키면 된다.
# file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
file.close()
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %%
# with 구문을 사용해서 파일을 open하면 with 내부의 내용이 모두 실행되고 난 후 자동으로 파일을 close 시킨다.
with open('bugsTOP100_1.txt', 'w') as file:
    file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
    for i in range(100):
        artist = artists[i].text.strip().split('\n')[0]
        title = titles[i].text.strip().split('\n')[0]
        data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
        file.write(data + '\n')
print('bugsTOP100_1.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100_1.txt 파일로 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('bugsTOP100.txt', 'r')
    # readlines() 메소드는 텍스트 파일의 내용 전체를 한꺼번에 읽어서 리스트로 변환한다.
    lines = file.readlines()
    for line in lines:
        print(line, end = '')
        # print(line.strip())
except:
    print('디스크에 데이터 파일이 없습니다.')
# Out:
# 2020-12-16 20:18:44.249801 현재 Bugs 뮤직 실시간 TOP 100
#   1위 태연 (TAEYEON) - What Do I Call You
#   2위 에피톤 프로젝트(Epitone Project) - 불면증 (Vocal by 윤하)
#   3위 이하이 - For You (Feat. Crush)
#   4위 태연 (TAEYEON) - Playlist
#   5위 태연 (TAEYEON) - To the moon
#   6위 스윙스(Swings) - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#   7위 미란이 - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   8위 태연 (TAEYEON) - 들불 (Wildfire)
#   9위 태연 (TAEYEON) - Galaxy
#  10위 Mariah Carey(머라이어 캐리) - All I Want for Christmas Is You
#  11위 백예린 (Yerin Baek) - Lovegame
#  12위 미란이 - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  13위 방탄소년단 - Life Goes On
#  14위 방탄소년단 - Dynamite
#  15위 Ariana Grande(아리아나 그란데) - Santa Tell Me
#  16위 노을 - 지켜줄게 (바니와 오빠들 X 노을)
#  17위 백예린 (Yerin Baek) - Hate you
#  18위 IZ*ONE(아이즈원) - Panorama
#  19위 황인욱 - 한잔이면 지워질까
#  20위 릴보이(lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#  21위 aespa - Black Mamba
#  22위 장범준 - 잠이 오질 않네요
#  23위 머쉬베놈(MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  24위 BLACKPINK - Lovesick Girls
#  25위 경서 - 밤하늘의 별을(2020)
#  26위 아이유(IU) - 미리 메리 크리스마스 (feat. 천둥 Of MBLAQ)
#  27위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  28위 TWICE (트와이스) - I CAN’T STOP ME
#  29위 이승기 - 잘할게
#  30위 Sia(시아) - Snowman
#  31위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  32위 코드 쿤스트 - 사라진 모든 것들에게(with ELLE KOREA)
#  33위 영준 [Brown Eyed Soul] - 달링 (Darling)
#  34위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  35위 원슈타인 - 적외선 카메라
#  36위 KHUNDI PANDA - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  37위 보아 (BoA) - Better
#  38위 잔나비 - 가을밤에 든 생각
#  39위 백예린 (Yerin Baek) - I am not your ocean anymore
#  40위 성시경 - 크리스마스니까
#  41위 여자친구(GFRIEND) - MAGO
#  42위 정승환 - 어김없이 이 거리에
#  43위 마마무(Mamamoo) - 딩가딩가 (Dingga)
#  44위 벤 - 혼술하고 싶은 밤
#  45위 백예린 (Yerin Baek) - 0415
#  46위 릴보이(lIlBOI) - Freak (Prod. Slom)
#  47위 양요섭 - 한 번에 알아본 사랑 (바른연애 길잡이 X 양요섭)
#  48위 KHUNDI PANDA - Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
#  49위 AKMU (악동뮤지션) - HAPPENING
#  50위 임창정 - 힘든 건 사랑이 아니다
#  51위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  52위 오마이걸(OH MY GIRL) - Dolphin
#  53위 Ariana Grande(아리아나 그란데) - 34+35
#  54위 박진영 - When We Disco (Duet with 선미)
#  55위 STAYC(스테이씨) - SO BAD
#  56위 방탄소년단 - 내 방을 여행하는 법
#  57위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  58위 머쉬베놈(MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. GroovyRoom)
#  59위 폴킴(Paul Kim) - 너도 아는
#  60위 015B - 니 눈이 보여 (Feat. 동하)
#  61위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  62위 백예린 (Yerin Baek) - You’re so lonely now, so you need me back by your side again
#  63위 임영웅 - 이제 나만 믿어요
#  64위 스탠딩 에그(Standing Egg) - 오래된 노래
#  65위 NCT U - 90's Love
#  66위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  67위 이승기 - 뻔한남자
#  68위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  69위 방탄소년단 - Blue & Grey
#  70위 환불원정대 - DON'T TOUCH ME
#  71위 릴보이(lIlBOI) - Bad News Cypher vol.2 (Feat. TakeOne)
#  72위 아이유(IU) - Blueming
#  73위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  74위 Maroon 5(마룬 파이브) - Memories
#  75위 백예린 (Yerin Baek) - Hall&Oates
#  76위 BLACKPINK - How You Like That
#  77위 래원 (Layone) - iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
#  78위 청하 - Bad Boy
#  79위 방탄소년단 - 잠시
#  80위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  81위 이하이 - 홀로
#  82위 백예린 (Yerin Baek) - Loveless
#  83위 아이유(IU) - 마음을 드려요
#  84위 백예린 (Yerin Baek) - Square (2017)
#  85위 Straight No Chaser(스트레이트 노 체이서) - Text Me Merry Christmas (feat. Kristen Bell)
#  86위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  87위 창모(CHANGMO) - METEOR
#  88위 김성규 - I'm Cold
#  89위 볼빨간사춘기 - Dancing Cartoon
#  90위 잔나비 - 주저하는 연인들을 위해
#  91위 권진아 - 평행선 (Light and Darkness)
#  92위 백예린 (Yerin Baek) - Ms. Delicate
#  93위 원슈타인 - 세상에 나쁜 개는 없다 (Feat. YDG, Zion.T) (Prod. Slom)
#  94위 화사(Hwa Sa) - 마리아 (Maria)
#  95위 백예린 (Yerin Baek) - I’ll be your family!
#  96위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
#  97위 아이유(IU) - 밤편지
#  98위 SG워너비 - Must Have Love (우리들의 겨울)
#  99위 조정석 - 아로하
# 100위 BLACKPINK - Pretty Savage
