# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
targetSite = 'https://www.melon.com/chart/index.htm'

# %%
# request = requests.get(targetSite)
# print(request) # <Response [406]>
# Out:
# <Response [406]>

# %%
# 헤더 정보 문제로 웹 사이트의 데이터를 읽어오지 못할 경우 아래와 같이 헤더 정보를 설정한 후 읽는다.
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers = header)
# print(request)
html = request.text
soup = BeautifulSoup(html, 'html.parser')

# %%
# 노래 제목 크롤링
titles = soup.findAll('div', {'class': 'ellipsis rank01'})
# print(titles)
# print(len(titles))

for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# 100
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
# Dynamite
# 밤하늘의 별을(2020)
# 잠이 오질 않네요
# What Do I Call You
# 힘든 건 사랑이 아니다
# All I Want For Christmas Is You
# 취기를 빌려 (취향저격 그녀 X 산들)
# Lovesick Girls
# Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
# Life Goes On
# 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
# Santa Tell Me
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 오래된 노래
# Freak (Prod. Slom)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
# 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 딩가딩가 (Dingga)
# When We Disco (Duet with 선미)
# DON'T TOUCH ME
# 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
# 혼술하고 싶은 밤
# 에잇(Prod.&Feat. SUGA of BTS)
# Snowman
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 늦은 밤 너의 집 앞 골목길에서
# 어떻게 지내 (Prod. By VAN.C)
# 뻔한남자
# How You Like That
# I CAN’T STOP ME
# 적외선 카메라
# 아로하
# 모든 날, 모든 순간 (Every day, Every Moment)
# Dolphin
# METEOR
# Blueming
# 가을밤에 든 생각
# 거짓말이라도 해서 널 보고싶어
# 사실 나는 (Feat.전건호)
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 마리아 (Maria)
# 눈누난나 (NUNU NANA)
# 크리스마스니까
# 서면역에서
# 홀로
# Memories
# 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 사랑은 지날수록 더욱 선명하게 남아
# Dance Monkey
# 한잔이면 지워질까
# 우리 왜 헤어져야 해
# 마음을 드려요
# 봄날
# Downtown Baby
# 부어라 비워라 (Tricker) (Prod. GroovyRoom)
# 사랑 못해, 남들 쉽게 다 하는 거
# 소확행
# 2002
# 살짝 설렜어 (Nonstop)
# 놓아줘 (with 태연)
# 시작
# 행복해
# 처음처럼
# Bad News Cypher vol.2 (Feat. TakeOne)
# 안녕
# 너도 아는
# Playlist
# Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
# Bad Boy
# 너를 만나
# Blue & Grey
# 내 방을 여행하는 법
# 사랑하게 될 줄 알았어
# 별을 담은 시 (Ode To The Stars)
# Panorama
# 이제 나만 믿어요
# Don't Start Now
# 잘할게
# Hate you
# 다시 여기 바닷가
# To the moon
# 12:45 (Stripped)
# ON
# Love poem
# iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
# Black Mamba
# 아무노래
# 어김없이 이 거리에
# AYA
# 들불 (Wildfire)
# Galaxy
# Paris In The Rain
# Maniac
# 윈윈 (Feat. 개코, BewhY) (Prod. BewhY)

# %%
# 아티스트 크롤링
artists = soup.findAll('span', {'class': 'checkEllipsis'})
# print(artists)
# print(len(artists))

for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[1])
    print(artist.text.strip().split('\n')[0])
# Out:
# 미란이 (Mirani), 먼치맨, Khundi Panda, 머쉬베놈 (MUSHVENOM)
# 릴보이 (lIlBOI)
# 방탄소년단
# 경서
# 장범준
# 태연 (TAEYEON)
# 임창정
# Mariah Carey
# 산들
# BLACKPINK
# 미란이 (Mirani)
# 방탄소년단
# 스윙스
# Ariana Grande
# Jawsh 685, Jason Derulo, 방탄소년단
# 스탠딩 에그
# 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk)
# 규현 (KYUHYUN)
# Khundi Panda
# 아이유
# 적재
# AKMU (악동뮤지션)
# 마마무 (Mamamoo)
# 박진영
# 환불원정대
# 머쉬베놈 (MUSHVENOM)
# 벤
# 아이유
# Sia
# 장범준
# 노을
# 오반 (OVAN)
# 이승기
# BLACKPINK
# TWICE (트와이스)
# 원슈타인
# 조정석
# 폴킴
# 오마이걸 (OH MY GIRL)
# 창모 (CHANGMO)
# 아이유
# 잔나비
# 백지영
# 경서예지
# 방탄소년단
# 화사 (Hwa Sa)
# 제시 (Jessi)
# 성시경, 박효신, 이석훈, 서인국, VIXX (빅스)
# 순순희
# 이하이
# Maroon 5
# 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone)
# 마크툽 (MAKTUB)
# 전상근
# Tones And I
# 황인욱
# 신예영
# 아이유
# 방탄소년단
# 블루 (BLOO)
# 머쉬베놈 (MUSHVENOM)
# 먼데이 키즈 (Monday Kiz)
# 임창정
# Anne-Marie
# 오마이걸 (OH MY GIRL)
# Crush
# 가호 (Gaho)
# 송하예
# 엠씨더맥스 (M.C the MAX)
# 릴보이 (lIlBOI)
# 폴킴
# 폴킴
# 태연 (TAEYEON)
# Khundi Panda
# 청하, Christopher
# 폴킴
# 방탄소년단
# 방탄소년단
# 전미도
# 마크툽 (MAKTUB), 이라온
# IZ*ONE (아이즈원)
# 임영웅
# Dua Lipa
# 이승기
# 백예린 (Yerin Baek)
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 태연 (TAEYEON)
# Etham
# 방탄소년단
# 아이유
# 래원 (Layone)
# aespa
# 지코 (ZICO)
# 정승환
# 마마무 (Mamamoo)
# 태연 (TAEYEON)
# 태연 (TAEYEON)
# Lauv
# Conan Gray
# 허성현 (Rose de Penny), dsel (디젤), 가오가이 (kaogaii), Untell (언텔)

# %%
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2020-12-16 20:59:56.636795
#   1위 미란이 (Mirani), 먼치맨, Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   2위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#   3위 방탄소년단 - Dynamite
#   4위 경서 - 밤하늘의 별을(2020)
#   5위 장범준 - 잠이 오질 않네요
#   6위 태연 (TAEYEON) - What Do I Call You
#   7위 임창정 - 힘든 건 사랑이 아니다
#   8위 Mariah Carey - All I Want For Christmas Is You
#   9위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  10위 BLACKPINK - Lovesick Girls
#  11위 미란이 (Mirani) - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  12위 방탄소년단 - Life Goes On
#  13위 스윙스 - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#  14위 Ariana Grande - Santa Tell Me
#  15위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  16위 스탠딩 에그 - 오래된 노래
#  17위 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk) - Freak (Prod. Slom)
#  18위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  19위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  20위 아이유 - 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)
#  21위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  22위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  23위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
#  24위 박진영 - When We Disco (Duet with 선미)
#  25위 환불원정대 - DON'T TOUCH ME
#  26위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  27위 벤 - 혼술하고 싶은 밤
#  28위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  29위 Sia - Snowman
#  30위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  31위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  32위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  33위 이승기 - 뻔한남자
#  34위 BLACKPINK - How You Like That
#  35위 TWICE (트와이스) - I CAN’T STOP ME
#  36위 원슈타인 - 적외선 카메라
#  37위 조정석 - 아로하
#  38위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  39위 오마이걸 (OH MY GIRL) - Dolphin
#  40위 창모 (CHANGMO) - METEOR
#  41위 아이유 - Blueming
#  42위 잔나비 - 가을밤에 든 생각
#  43위 백지영 - 거짓말이라도 해서 널 보고싶어
#  44위 경서예지 - 사실 나는 (Feat.전건호)
#  45위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  46위 화사 (Hwa Sa) - 마리아 (Maria)
#  47위 제시 (Jessi) - 눈누난나 (NUNU NANA)
#  48위 성시경, 박효신, 이석훈, 서인국, VIXX (빅스) - 크리스마스니까
#  49위 순순희 - 서면역에서
#  50위 이하이 - 홀로
#  51위 Maroon 5 - Memories
#  52위 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
#  53위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  54위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  55위 Tones And I - Dance Monkey
#  56위 황인욱 - 한잔이면 지워질까
#  57위 신예영 - 우리 왜 헤어져야 해
#  58위 아이유 - 마음을 드려요
#  59위 방탄소년단 - 봄날
#  60위 블루 (BLOO) - Downtown Baby
#  61위 머쉬베놈 (MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. GroovyRoom)
#  62위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  63위 임창정 - 소확행
#  64위 Anne-Marie - 2002
#  65위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  66위 Crush - 놓아줘 (with 태연)
#  67위 가호 (Gaho) - 시작
#  68위 송하예 - 행복해
#  69위 엠씨더맥스 (M.C the MAX) - 처음처럼
#  70위 릴보이 (lIlBOI) - Bad News Cypher vol.2 (Feat. TakeOne)
#  71위 폴킴 - 안녕
#  72위 폴킴 - 너도 아는
#  73위 태연 (TAEYEON) - Playlist
#  74위 Khundi Panda - Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
#  75위 청하, Christopher - Bad Boy
#  76위 폴킴 - 너를 만나
#  77위 방탄소년단 - Blue & Grey
#  78위 방탄소년단 - 내 방을 여행하는 법
#  79위 전미도 - 사랑하게 될 줄 알았어
#  80위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
#  81위 IZ*ONE (아이즈원) - Panorama
#  82위 임영웅 - 이제 나만 믿어요
#  83위 Dua Lipa - Don't Start Now
#  84위 이승기 - 잘할게
#  85위 백예린 (Yerin Baek) - Hate you
#  86위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  87위 태연 (TAEYEON) - To the moon
#  88위 Etham - 12:45 (Stripped)
#  89위 방탄소년단 - ON
#  90위 아이유 - Love poem
#  91위 래원 (Layone) - iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
#  92위 aespa - Black Mamba
#  93위 지코 (ZICO) - 아무노래
#  94위 정승환 - 어김없이 이 거리에
#  95위 마마무 (Mamamoo) - AYA
#  96위 태연 (TAEYEON) - 들불 (Wildfire)
#  97위 태연 (TAEYEON) - Galaxy
#  98위 Lauv - Paris In The Rain
#  99위 Conan Gray - Maniac
# 100위 허성현 (Rose de Penny), dsel (디젤), 가오가이 (kaogaii), Untell (언텔) - 윈윈 (Feat. 개코, BewhY) (Prod. BewhY)

# %%
file = open('melonTOP100.txt', 'w')
file.write('{} 현재 Melon 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
file.close()
print('MelonTOP100.txt 파일로 쓰기 완료')
# Out:
# MelonTOP100.txt 파일로 쓰기 완료

# %%
try:
    file = open('MelonTOP100.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line, end = '')
except:
    print('디스크에 데이터 파일이 없습니다.')
# Out:
# 2020-12-16 21:00:54.746603 현재 Melon 뮤직 실시간 TOP 100
#   1위 미란이 (Mirani), 먼치맨, Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   2위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#   3위 방탄소년단 - Dynamite
#   4위 경서 - 밤하늘의 별을(2020)
#   5위 장범준 - 잠이 오질 않네요
#   6위 태연 (TAEYEON) - What Do I Call You
#   7위 임창정 - 힘든 건 사랑이 아니다
#   8위 Mariah Carey - All I Want For Christmas Is You
#   9위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  10위 BLACKPINK - Lovesick Girls
#  11위 미란이 (Mirani) - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  12위 방탄소년단 - Life Goes On
#  13위 스윙스 - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#  14위 Ariana Grande - Santa Tell Me
#  15위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  16위 스탠딩 에그 - 오래된 노래
#  17위 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk) - Freak (Prod. Slom)
#  18위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  19위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  20위 아이유 - 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)
#  21위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  22위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  23위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
#  24위 박진영 - When We Disco (Duet with 선미)
#  25위 환불원정대 - DON'T TOUCH ME
#  26위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  27위 벤 - 혼술하고 싶은 밤
#  28위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  29위 Sia - Snowman
#  30위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  31위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  32위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  33위 이승기 - 뻔한남자
#  34위 BLACKPINK - How You Like That
#  35위 TWICE (트와이스) - I CAN’T STOP ME
#  36위 원슈타인 - 적외선 카메라
#  37위 조정석 - 아로하
#  38위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  39위 오마이걸 (OH MY GIRL) - Dolphin
#  40위 창모 (CHANGMO) - METEOR
#  41위 아이유 - Blueming
#  42위 잔나비 - 가을밤에 든 생각
#  43위 백지영 - 거짓말이라도 해서 널 보고싶어
#  44위 경서예지 - 사실 나는 (Feat.전건호)
#  45위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  46위 화사 (Hwa Sa) - 마리아 (Maria)
#  47위 제시 (Jessi) - 눈누난나 (NUNU NANA)
#  48위 성시경, 박효신, 이석훈, 서인국, VIXX (빅스) - 크리스마스니까
#  49위 순순희 - 서면역에서
#  50위 이하이 - 홀로
#  51위 Maroon 5 - Memories
#  52위 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
#  53위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  54위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  55위 Tones And I - Dance Monkey
#  56위 황인욱 - 한잔이면 지워질까
#  57위 신예영 - 우리 왜 헤어져야 해
#  58위 아이유 - 마음을 드려요
#  59위 방탄소년단 - 봄날
#  60위 블루 (BLOO) - Downtown Baby
#  61위 머쉬베놈 (MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. GroovyRoom)
#  62위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  63위 임창정 - 소확행
#  64위 Anne-Marie - 2002
#  65위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  66위 Crush - 놓아줘 (with 태연)
#  67위 가호 (Gaho) - 시작
#  68위 송하예 - 행복해
#  69위 엠씨더맥스 (M.C the MAX) - 처음처럼
#  70위 릴보이 (lIlBOI) - Bad News Cypher vol.2 (Feat. TakeOne)
#  71위 폴킴 - 안녕
#  72위 폴킴 - 너도 아는
#  73위 태연 (TAEYEON) - Playlist
#  74위 Khundi Panda - Hero (Feat. JUSTHIS, Golden) (Prod. GroovyRoom)
#  75위 청하, Christopher - Bad Boy
#  76위 폴킴 - 너를 만나
#  77위 방탄소년단 - Blue & Grey
#  78위 방탄소년단 - 내 방을 여행하는 법
#  79위 전미도 - 사랑하게 될 줄 알았어
#  80위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
#  81위 IZ*ONE (아이즈원) - Panorama
#  82위 임영웅 - 이제 나만 믿어요
#  83위 Dua Lipa - Don't Start Now
#  84위 이승기 - 잘할게
#  85위 백예린 (Yerin Baek) - Hate you
#  86위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  87위 태연 (TAEYEON) - To the moon
#  88위 Etham - 12:45 (Stripped)
#  89위 방탄소년단 - ON
#  90위 아이유 - Love poem
#  91위 래원 (Layone) - iii (Feat. 베이식, Kid Milli & 팔로알토) (Prod. 코드 쿤스트)
#  92위 aespa - Black Mamba
#  93위 지코 (ZICO) - 아무노래
#  94위 정승환 - 어김없이 이 거리에
#  95위 마마무 (Mamamoo) - AYA
#  96위 태연 (TAEYEON) - 들불 (Wildfire)
#  97위 태연 (TAEYEON) - Galaxy
#  98위 Lauv - Paris In The Rain
#  99위 Conan Gray - Maniac
# 100위 허성현 (Rose de Penny), dsel (디젤), 가오가이 (kaogaii), Untell (언텔) - 윈윈 (Feat. 개코, BewhY) (Prod. BewhY)
