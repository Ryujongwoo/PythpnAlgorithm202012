# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=1 => 1 ~ 50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=2 => 51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg='
for i in range(1, 5):
    print('{}{}'.format(url, i))
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg='
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    # print(targetSite)
    request = requests.get(targetSite, headers = header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for title in titles:
        # print(title.text.strip())
        # print(title.text.split('\n')[1])
        print(title.text.strip().split('\n')[0])
# Out:
# For You (Feat. Crush)
# What Do I Call You
# VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 한잔이면 지워질까
# 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. by 코드 쿤스트)
# Hate you
# Dynamite
# 내일이 오면 (Feat. 기리보이 & BIG Naughty (서동현))
# 밤하늘의 별을 (2020)
# Achoo (Feat. pH-1 & HAON) (Prod. by GroovyRoom)
# Life Goes On
# 잠이 오질 않네요
# 혼술하고 싶은 밤
# 고독하구만 (Feat. 수퍼비) (Prod. by GroovyRoom)
# Playlist
# 뿌리 (Feat. JUSTHIS) (Prod. by GroovyRoom)
# All I Want for Christmas Is You
# 지켜줄게 (바니와 오빠들 X 노을)
# Santa Tell Me
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 잘할게
# 힘든 건 사랑이 아니다
# Lovesick Girls
# Panorama
# Snowman
# 취기를 빌려 (취향저격 그녀 X 산들)
# Freak (Prod. by Slom)
# To the moon
# 이제 나만 믿어요
# 미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)
# 어김없이 이 거리에
# 오래된 노래
# 적외선 카메라
# Galaxy
# 들불 (Wildfire)
# 딩가딩가 (Dingga)
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# Hero (Feat. JUSTHIS & Golden) (Prod. by GroovyRoom)
# 가을밤에 든 생각
# 뻔한남자
# 내 방을 여행하는 법
# 오래된 노래
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# HERO
# Bad News Cypher Vol.2 (Feat. TakeOne)
# I CAN'T STOP ME
# 에잇 (Prod. & Feat. SUGA of BTS)
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# Blue & Grey

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201216&hh=21&rtm=Y&pg='
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    # print(targetSite)
    request = requests.get(targetSite, headers = header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    print(len(artists)) # 55

    for artist in artists[5:]:
        # print(artist.text.strip())
        # print(artist.text.split('\n')[1])
        print(artist.text.strip().split('\n')[0])
# Out:
# 55
# 이하이
# 태연 (TAEYEON)
# 미란이 (Mirani) & 먼치맨 & Khundi Panda & 머쉬베놈 (MUSHVENOM)
# 황인욱
# 스윙스 (Swings)
# 백예린 (Yerin Baek)
# 방탄소년단
# 릴보이 (lIlBOI)
# 경서
# 미란이 (Mirani)
# 방탄소년단
# 장범준
# 벤
# 머쉬베놈 (MUSHVENOM)
# 태연 (TAEYEON)
# Khundi Panda
# Mariah Carey
# 노을
# Ariana Grande
# Jawsh 685 & Jason Derulo & 방탄소년단
# 이승기
# 임창정
# BLACKPINK
# IZ*ONE (아이즈원)
# Sia
# 산들
# 릴보이 (lIlBOI) & 원슈타인 & Chillin Homie & 스카이민혁 (Skyminhyuk)
# 태연 (TAEYEON)
# 임영웅
# 아이유 (IU)
# 정승환
# Standing Egg (스탠딩 에그)
# 원슈타인
# 태연 (TAEYEON)
# 태연 (TAEYEON)
# 마마무(Mamamoo)
# 방탄소년단
# 규현 (KYUHYUN)
# Khundi Panda
# 잔나비
# 이승기
# 방탄소년단
# 임영웅
# 장범준
# 임영웅
# 릴보이 (lIlBOI)
# TWICE (트와이스)
# 아이유 (IU)
# 적재
# 방탄소년단

# %%
genie = []
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    time.sleep(1)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    for i in range(len(titles)):
        genie.append([
            titles[i].text.strip().split('\n')[0], 
            artists[i + 5].text.strip().split('\n')[0]
        ])

# %%
for i in range(len(genie)):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0]))
# Out:
#   1위 이하이 - For You (Feat. Crush)
#   2위 태연 (TAEYEON) - What Do I Call You
#   3위 미란이 (Mirani) & 먼치맨 & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#   4위 황인욱 - 한잔이면 지워질까
#   5위 스윙스 (Swings) - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. by 코드 쿤스트)
#   6위 백예린 (Yerin Baek) - Hate you
#   7위 방탄소년단 - Dynamite
#   8위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이 & BIG Naughty (서동현))
#   9위 경서 - 밤하늘의 별을 (2020)
#  10위 미란이 (Mirani) - Achoo (Feat. pH-1 & HAON) (Prod. by GroovyRoom)
#  11위 방탄소년단 - Life Goes On
#  12위 장범준 - 잠이 오질 않네요
#  13위 벤 - 혼술하고 싶은 밤
#  14위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. by GroovyRoom)
#  15위 태연 (TAEYEON) - Playlist
#  16위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  17위 Mariah Carey - All I Want for Christmas Is You
#  18위 노을 - 지켜줄게 (바니와 오빠들 X 노을)
#  19위 Ariana Grande - Santa Tell Me
#  20위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  21위 이승기 - 잘할게
#  22위 임창정 - 힘든 건 사랑이 아니다
#  23위 BLACKPINK - Lovesick Girls
#  24위 IZ*ONE (아이즈원) - Panorama
#  25위 Sia - Snowman
#  26위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  27위 릴보이 (lIlBOI) & 원슈타인 & Chillin Homie & 스카이민혁 (Skyminhyuk) - Freak (Prod. by Slom)
#  28위 태연 (TAEYEON) - To the moon
#  29위 임영웅 - 이제 나만 믿어요
#  30위 아이유 (IU) - 미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)
#  31위 정승환 - 어김없이 이 거리에
#  32위 Standing Egg (스탠딩 에그) - 오래된 노래
#  33위 원슈타인 - 적외선 카메라
#  34위 태연 (TAEYEON) - Galaxy
#  35위 태연 (TAEYEON) - 들불 (Wildfire)
#  36위 마마무(Mamamoo) - 딩가딩가 (Dingga)
#  37위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  38위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  39위 Khundi Panda - Hero (Feat. JUSTHIS & Golden) (Prod. by GroovyRoom)
#  40위 잔나비 - 가을밤에 든 생각
#  41위 이승기 - 뻔한남자
#  42위 방탄소년단 - 내 방을 여행하는 법
#  43위 임영웅 - 오래된 노래
#  44위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  45위 임영웅 - HERO
#  46위 릴보이 (lIlBOI) - Bad News Cypher Vol.2 (Feat. TakeOne)
#  47위 TWICE (트와이스) - I CAN'T STOP ME
#  48위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
#  49위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  50위 방탄소년단 - Blue & Grey
#  51위 환불원정대 - DON'T TOUCH ME
#  52위 머쉬베놈 (MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. by GroovyRoom)
#  53위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
#  54위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  55위 임영웅 - 어느 60대 노부부이야기
#  56위 방탄소년단 - 봄날
#  57위 아이유 (IU) - Blueming
#  58위 박진영 - When We Disco (Duet With 선미)
#  59위 청하 & Christopher - Bad Boy
#  60위 폴킴 - 너도 아는
#  61위 창모 (CHANGMO) - METEOR
#  62위 스윙스 (Swings) & 맥대디 (Mckdaddy) & Khakii (카키) & 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. by 코드 쿤스트)
#  63위 김호중 - 만개 (Prod. 신지후)
#  64위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  65위 BLACKPINK - How You Like That
#  66위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  67위 래원 (Layone) - iii (Feat. 베이식 & Kid Milli & 팔로알토) (Prod. by 코드 쿤스트)
#  68위 방탄소년단 - 잠시
#  69위 김호중 - 나보다 더 사랑해요
#  70위 오마이걸 (OH MY GIRL) - Dolphin
#  71위 김호중 - 살았소
#  72위 마마무(Mamamoo) - AYA
#  73위 임영웅 - 바램
#  74위 양요섭 - 한 번에 알아본 사랑 (바른연애 길잡이 X 양요섭)
#  75위 Anne-Marie - 2002
#  76위 경서예지 - 사실 나는 (Feat. 전건호)
#  77위 Tones And I - Dance Monkey
#  78위 백예린 (Yerin Baek) - Lovegame
#  79위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  80위 조정석 - 아로하
#  81위 방탄소년단 - Stay
#  82위 화사 (Hwa Sa) - 마리아 (Maria)
#  83위 방탄소년단 - ON
#  84위 aespa - Black Mamba
#  85위 제시 - 눈누난나 (NUNU NANA)
#  86위 방탄소년단 - 병
#  87위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
#  88위 임영웅 - 보라빛 엽서
#  89위 가호 (Gaho) - 시작
#  90위 성시경 & 박효신 & 이석훈 & 서인국 & VIXX (빅스) - 크리스마스니까
#  91위 아이유 (IU) - 마음을 드려요
#  92위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
#  93위 Maroon 5 - Memories
#  94위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
#  95위 임영웅 - 이제 나만 믿어요 (Piano by 조영수)
#  96위 이하이 - 홀로
#  97위 김호중 - 남 몰래 흘리는 눈물 (Una Furtiva Lagrima)
#  98위 임창정 - 소확행
#  99위 블루 (BLOO) - Downtown Baby
# 100위 여자친구 (GFRIEND) - MAGO
# 101위 폴킴 - 안녕
# 102위 김호중 - 지금 이 순간 (This is the Moment)
# 103위 에피톤 프로젝트 (Epitone Project) - 불면증 (Vocal by 윤하)
# 104위 원슈타인 - 세상에 나쁜 개는 없다 (Feat. YDG & Zion.T) (Prod. by Slom)
# 105위 폴킴 - 너를 만나
# 106위 김호중 - 위대한 사랑 (Un Amore Cosi Grande)
# 107위 신예영 - 우리 왜 헤어져야 해
# 108위 임영웅 - 계단말고 엘리베이터
# 109위 김성규 - I'm Cold
# 110위 임영웅 - 어느날 문득
# 111위 김호중 - 풍경
# 112위 김호중 - 별은 빛나건만 (E Lucevan Le Stelle)
# 113위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
# 114위 GOT7 (갓세븐) - LAST PIECE
# 115위 백지영 - 거짓말이라도 해서 널 보고싶어
# 116위 임영웅 - 미워요
# 117위 Dua Lipa - Don't Start Now
# 118위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#
 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 178위 Wham! - Last Christmas
# 179위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
# 180위 김성규 - DIVIN'
# 181위 Pink Sweat$ - At My Worst
# 182위 Christopher - Bad
# 183위 Ed Sheeran - Shape Of You
# 184위 Mariah Carey - Oh Santa! (Feat. Ariana Grande & Jennifer Hudson)
# 185위 싱어게인 63호 가수 - 누구 없소
# 186위 NCT U - 90's Love
# 187위 Ava Max - Christmas Without You
# 188위 숀 (SHAUN) - Way Back Home
# 189위 진민호 - 반만
# 190위 케이시 (Kassy) - 행복하니
# 191위 BLACKPINK - Pretty Savage
# 192위 미란이 (Mirani) - Part Time (Feat. Queen WA$ABII (퀸 와사비)) (Prod. by GroovyRoom & BOYCOLD)
# 193위 BLACKPINK - Ice Cream (With Selena Gomez)
# 194위 긱스 (Geeks) - Officially Missing You
# 195위 김종국 - 지우고 아플 사랑은..
# 196위 휘인 (Whee In) - 내 눈물 모아
# 197위 창모 (CHANGMO) - 광장동에서
# 198위 송하예 - 니 소식
# 199위 임창정 - 하루도 그대를 사랑하지 않은 적이 없었다
# 200위 카이 (KAI) - 음 (Mmmh)

# %%
file = open('genieTOP200.txt', 'w')
file.write('{} 현재 Genie 뮤직 실시간 TOP 200\n'.format(dt.now()))
for i in range(200):
    data = '{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0])
    file.write(data + '\n')
file.close()
print('GenieTOP200.txt 파일로 쓰기 완료')
# Out:
# GenieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('GenieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line, end = '')
except:
    print('디스크에 데이터 파일이 없습니다.')
# Out:
# 2020-12-21 19:12:12.615762 현재 Genie 뮤직 실시간 TOP 200
#   1위 이하이 - For You (Feat. Crush)
#   2위 태연 (TAEYEON) - What Do I Call You
#   3위 미란이 (Mirani) & 먼치맨 & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#   4위 황인욱 - 한잔이면 지워질까
#   5위 스윙스 (Swings) - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. by 코드 쿤스트)
#   6위 백예린 (Yerin Baek) - Hate you
#   7위 방탄소년단 - Dynamite
#   8위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이 & BIG Naughty (서동현))
#   9위 경서 - 밤하늘의 별을 (2020)
#  10위 미란이 (Mirani) - Achoo (Feat. pH-1 & HAON) (Prod. by GroovyRoom)
#  11위 방탄소년단 - Life Goes On
#  12위 장범준 - 잠이 오질 않네요
#  13위 벤 - 혼술하고 싶은 밤
#  14위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. by GroovyRoom)
#  15위 태연 (TAEYEON) - Playlist
#  16위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  17위 Mariah Carey - All I Want for Christmas Is You
#  18위 노을 - 지켜줄게 (바니와 오빠들 X 노을)
#  19위 Ariana Grande - Santa Tell Me
#  20위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  21위 이승기 - 잘할게
#  22위 임창정 - 힘든 건 사랑이 아니다
#  23위 BLACKPINK - Lovesick Girls
#  24위 IZ*ONE (아이즈원) - Panorama
#  25위 Sia - Snowman
#  26위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  27위 릴보이 (lIlBOI) & 원슈타인 & Chillin Homie & 스카이민혁 (Skyminhyuk) - Freak (Prod. by Slom)
#  28위 태연 (TAEYEON) - To the moon
#  29위 임영웅 - 이제 나만 믿어요
#  30위 아이유 (IU) - 미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)
#  31위 정승환 - 어김없이 이 거리에
#  32위 Standing Egg (스탠딩 에그) - 오래된 노래
#  33위 원슈타인 - 적외선 카메라
#  34위 태연 (TAEYEON) - Galaxy
#  35위 태연 (TAEYEON) - 들불 (Wildfire)
#  36위 마마무(Mamamoo) - 딩가딩가 (Dingga)
#  37위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  38위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  39위 Khundi Panda - Hero (Feat. JUSTHIS & Golden) (Prod. by GroovyRoom)
#  40위 잔나비 - 가을밤에 든 생각
#  41위 이승기 - 뻔한남자
#  42위 방탄소년단 - 내 방을 여행하는 법
#  43위 임영웅 - 오래된 노래
#  44위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  45위 임영웅 - HERO
#  46위 릴보이 (lIlBOI) - Bad News Cypher Vol.2 (Feat. TakeOne)
#  47위 TWICE (트와이스) - I CAN'T STOP ME
#  48위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
#  49위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  50위 방탄소년단 - Blue & Grey
#  51위 환불원정대 - DON'T TOUCH ME
#  52위 머쉬베놈 (MUSHVENOM) - 부어라 비워라 (Tricker) (Prod. by GroovyRoom)
#  53위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
#  54위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  55위 임영웅 - 어느 60대 노부부이야기
#  56위 방탄소년단 - 봄날
#  57위 아이유 (IU) - Blueming
#  58위 박진영 - When We Disco (Duet With 선미)
#  59위 청하 & Christopher - Bad Boy
#  60위 폴킴 - 너도 아는
#  61위 창모 (CHANGMO) - METEOR
#  62위 스윙스 (Swings) & 맥대디 (Mckdaddy) & Khakii (카키) & 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. by 코드 쿤스트)
#  63위 김호중 - 만개 (Prod. 신지후)
#  64위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  65위 BLACKPINK - How You Like That
#  66위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  67위 래원 (Layone) - iii (Feat. 베이식 & Kid Milli & 팔로알토) (Prod. by 코드 쿤스트)
#  68위 방탄소년단 - 잠시
#  69위 김호중 - 나보다 더 사랑해요
#  70위 오마이걸 (OH MY GIRL) - Dolphin
#  71위 김호중 - 살았소
#  72위 마마무(Mamamoo) - AYA
#  73위 임영웅 - 바램
#  74위 양요섭 - 한 번에 알아본 사랑 (바른연애 길잡이 X 양요섭)
#  75위 Anne-Marie - 2002
#  76위 경서예지 - 사실 나는 (Feat. 전건호)
#  77위 Tones And I - Dance Monkey
#  78위 백예린 (Yerin Baek) - Lovegame
#  79위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  80위 조정석 - 아로하
#  81위 방탄소년단 - Stay
#  82위 화사 (Hwa Sa) - 마리아 (Maria)
#  83위 방탄소년단 - ON
#  84위 aespa - Black Mamba
#  85위 제시 - 눈누난나 (NUNU NANA)
#  86위 방탄소년단 - 병
#  87위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
#  88위 임영웅 - 보라빛 엽서
#  89위 가호 (Gaho) - 시작
#  90위 성시경 & 박효신 & 이석훈 & 서인국 & VIXX (빅스) - 크리스마스니까
#  91위 아이유 (IU) - 마음을 드려요
#  92위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
#  93위 Maroon 5 - Memories
#  94위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
#  95위 임영웅 - 이제 나만 믿어요 (Piano by 조영수)
#  96위 이하이 - 홀로
#  97위 김호중 - 남 몰래 흘리는 눈물 (Una Furtiva Lagrima)
#  98위 임창정 - 소확행
#  99위 블루 (BLOO) - Downtown Baby
# 100위 여자친구 (GFRIEND) - MAGO
# 101위 폴킴 - 안녕
# 102위 김호중 - 지금 이 순간 (This is the Moment)
# 103위 에피톤 프로젝트 (Epitone Project) - 불면증 (Vocal by 윤하)
# 104위 원슈타인 - 세상에 나쁜 개는 없다 (Feat. YDG & Zion.T) (Prod. by Slom)
# 105위 폴킴 - 너를 만나
# 106위 김호중 - 위대한 사랑 (Un Amore Cosi Grande)
# 107위 신예영 - 우리 왜 헤어져야 해
# 108위 임영웅 - 계단말고 엘리베이터
# 109위 김성규 - I'm Cold
# 110위 임영웅 - 어느날 문득
# 111위 김호중 - 풍경
# 112위 김호중 - 별은 빛나건만 (E Lucevan Le Stelle)
# 113위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
# 114위 GOT7 (갓세븐) - LAST PIECE
# 115위 백지영 - 거짓말이라도 해서 널 보고싶어
# 116위 임영웅 - 미워요
# 117위 Dua Lipa - Don't Start Now
# 118위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 119위 etham - 12 : 45 (Stripped)
# 120위 김호중 - 여자의 마음 (La Donna E Mobile)
# 121위 김호중 - 나를 잊지 말아요 (Non Ti Scorda Di Me)
# 122위 순순희 - 서면역에서
# 123위 태연 (TAEYEON) - 사계 (Four Seasons)
# 124위 김호중 - 오 솔레미오 (O Sole Mio)
# 125위 김호중 - 무정한 마음 (Core 'Ngrato)
# 126위 김호중 - 아침의 노래 (Mattinata)
# 127위 김호중 - 페데리코의 탄식 (Lamento Di Federico)
# 128위 잔나비 - 주저하는 연인들을 위해
# 129위 볼빨간사춘기 - Dancing Cartoon
# 130위 이예준 - 그날에 나는 맘이 편했을까
# 131위 마미손 - 사랑은 (Feat. 원슈타인)
# 132위 방탄소년단 - Dynamite (Holiday Remix)
# 133위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 134위 V.O.S - 다시 만날까 봐
# 135위 MINO (송민호) - 도망가
# 136위 백예린 (Yerin Baek) - 0415
# 137위 허성현 (Rose de Penny) & dsel (디젤) & 가오가이 (kaogaii) & Untell (언텔) - 윈윈 (Feat. 개코 & BewhY) (Prod. by BewhY)
# 138위 지코 (ZICO) - 아무노래
# 139위 장범준 - 노래방에서
# 140위 Conan Gray - Maniac
# 141위 임재현 - 사랑에 연습이 있었다면 (Prod. by 2soo)
