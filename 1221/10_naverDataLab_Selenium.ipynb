# %%
# selenium을 사용하기 위해 selenium을 설치하고 import 한다.
# !pip install selenium

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# selenium을 사용해 가상 크롬을 실행한다. => 사용중인 크롬 버전과 같은 버전의 크롬 드라이버를 다운받는다.
driver = webdriver.Chrome('./chromedriver.exe')
# get() 메소드로 가상 크롬에 크롤링할 타겟 사이트를 띄운다.
driver.get('https://www.naver.com')

html = driver.page_source
print(html)
# Out:
# <html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"><head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20201119.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_201028.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1">   <script>document.domain="naver.com",window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent;window.nmain.isIE=navigator.appName&&navigator.appName.indexOf("Explorer")>0&&ua.toLocaleLowerCase().indexOf("msie 10.0")<0,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode</script> <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINESS_1","unit":"SU10577","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000166","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_2","tb":"BUSINESS_1","unit":"SU10578","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CARGAME":{"menu":"CARGAME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000167","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_1","tb":"CARGAME_1","unit":"SU10587","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000168","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_2","tb":"CARGAME_1","unit":"SU10588","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CHINA":{"menu":"CHINA","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000169","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_1","tb":"CHINA_1","unit":"SU10591","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000170","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_2","tb":"CHINA_1","unit":"SU10592","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"DESIGN":{"menu":"DESIGN","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000171","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_1","tb":"DESIGN_1","unit":"SU10569","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000172","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_2","tb":"DESIGN_1","unit":"SU10570","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"FARM":{"menu":"FARM","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000173","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_farm_1","tb":"FARM_1","unit":"SU10561","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000174","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_ma ...
# svt: 20201221213243,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '09680101',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb406-->"; </script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/common/min/probe.min.js" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/external.f7eebdcb.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/preload.19891a82.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/polyfill_async.f98bbe5a.js?o=www" type="text/javascript" crossorigin="anonymous" async=""></script>  <script src="https://pm.pstatic.net/dist/js/vendors~search.c2a0c3df.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/search.a69bb735.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.a0c019da.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/vendors~nmain.f696c04e.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.0e781bcf.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> <style>.ly_inputko {
# 	position: absolute;
# 	top: 38px;
# 	left: 404px;
# 	z-index: 900;
# 	width: 313px;
# 	padding: 0 10px;
# 	border: 1px solid #b8b8b8;
# 	line-height: 14px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko.ly_inputko_over {
# 	border: 1px solid #72747f;
# 	cursor: move;
# }
#
# .ly_inputko button {
# 	border: 0;
# 	background: none;
# 	cursor: pointer;
# }
#
# .ly_inputko .tab_inkey {
# 	display: inline-block;
# 	position: absolute;
# 	top: 15px;
# 	left: 10px;
# 	width: 78px;
# 	height: 11px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -80px -660px;
# }
#
# .ly_inputko .tab_inkey button {
# 	display: block;
# 	width: 78px;
# 	height: 11px;
# }
#
# .ly_inputko .inkeyon {
# 	background-position: -80px -640px;
# }
#
# .ly_inputko .tab_inms {
# 	display: inline-block;
# 	position: absolute;
# 	top: 15px;
# 	left: 108px;
# 	width: 78px;
# 	height: 11px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -174px -660px;
# }
#
# .ly_inputko .tab_inms button {
# 	display: block;
# 	width: 78px;
# 	height: 11px;
# }
#
# .ly_inputko .inmson {
# 	background-position: -174px -640px;
# }
#
# .ly_inputko .bar {
# 	position: absolute;
# 	top: 16px;
# 	left: 93px;
# }
#
# .ly_inputko .inputko_info {
# 	clear: both;
# 	position: relative;
# 	z-index: 2;
# 	width: 100%;
# 	padding: 9px 0 0;
# 	background: #f6f6f6 url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp_x.gif) repeat-x;
# }
#
# .ly_inputko .inputko_info li {
# 	padding: 2px 0 0 8px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bu_sp.gif) no-repeat 0 -393px;
# 	font-size: 11px;
# 	color: #333;
# 	letter-spacing: -1px;
# 	text-align: left;
# }
#
# .ly_inputko .inputko_info li span {
# 	display: inline-block;
# 	width: 9px;
# 	height: 9px;
# 	*height: 11px;
# 	margin: 0 1px 0 2px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bu_sp.gif) no-repeat 0 -60px;
# }
#
# .ly_inputko .inputko_info li em {
# 	color: #666;
# }
#
# .ly_inputko .btn_ly_cl {
# 	position: absolute;
# 	top: 12px;
# 	right: 12px;
# 	width: 12px;
# 	height: 12px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -60px -80px;
# }
#
# .ly_inputko .btn_ly_cl button {
# 	width: 12px;
# 	height: 12px;
# }
#
# .ly_inputko .setkorhelp {
# 	margin: 4px 0 12px 5px;
# 	text-align: left;
# }
#
# .ly_inputko .setkorhelp a {
# 	font-size: 11px;
# 	color: #666;
# 	letter-spacing: -1px;
# 	text-decoration: underline;
# }
#
# /* keyboard */
# .ly_inputko .inputko_keyboard {
# 	width: 313px;
# 	margin-top: 39px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko .keyboard {
# 	position: relative;
# 	z-index: 2;
# 	height: 105px;
# 	padding-bottom: 14px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko .keyboard_info {
# 	overflow: auto;
# 	width: 313px;
# 	height: 105px;
# }
#
# .ly_inputko .keyboard_info h3 {
# 	font-size: 12px;
# }
#
# .ly_inputko .keyboard_info h4 {
# 	clear: both;
# 	font-size: 11px;
# }
#
# .ly_inputko .keyboard_info li {
# 	float: left;
# 	margin-right: 5px;
# 	font-size: 11px;
# }
#
# .ly_inputko .keyboard_img {
# 	position: absolute;
# 	top: 0;
# 	left: 0;
# 	width: 313px;
# 	height: 105px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat;
# }
#
# .ly_inputko .inputko_keyboard .setkorhelp {
# 	position: relative;
# 	z-index: 2;
# 	margin: 0 0 0 8px;
# 	padding: 4px 0 12px;
# 	background-color: #f6f6f6;
# }
#
# /* mouse */
# .ly_inputko .inputko_mouse {
# 	width: 313px;
# 	margin-top: 57px;
# }
#
# .ly_inputko .inputko_mouse .btn_inko {
# 	position: absolute;
# 	z-index: 1;
# 	width: 25px;
# 	height: 25px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat 0 -280px;
# }
#
# .ly_inputko .inputko_mouse .btn_inko button {
# 	width: 25px;
# 	height: 25px;
# }
#
# .ly_inputko .inputko_mouse .inputko_info {
# 	z-index: 1;
# 	margin-top: 10px;
# }
#
# .ly_inputko .inputko_mouse .bar2 {
# 	position: absolute;
# 	top: 39px;
# 	left: 34px;
# 	color: #ddd;
# }
#
# .ly_inputko .inputko_mouse .inputko_info li {
# 	padding: 2px 0 0 4px;
# 	background: none;
# }
#
# .ly_inputko .mouse_kor, .mouse_eng {
# 	display: none;
# }
#
# .ly_inputko .btn_kor {
# 	position: absolute;
# 	top: 40px;
# 	left: 11px;
# 	z-index: 1;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -380px -40px;
# }
#
# .ly_inputko .btn_kor_on {
# 	position: absolute;
# 	top: 40px;
# 	left: 11px;
# 	z-index: 1;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -420px -40px;
# }
#
# .ly_inputko .btn_eng {
# 	position: absolute;
# 	top: 40px;
# 	left: 43px;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -380px -60px;
# }
#
# .ly_inputko .btn_eng_on {
# 	position: absolute;
# 	top: 40px;
# 	left: 43px;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -420px -60px;
# }
#
# .ly_inputko .btn_kor button, .ly_inputko .btn_kor_on button, .ly_inputko .btn_eng button, .ly_inputko .btn_eng_on button {
# 	display: block;
# 	width: 22px;
# 	height: 11px;
# }
#
# .ly_inputko .btn_mouse {
# 	overflow: hidden;
# 	clear: both;
# 	width: 131px;
# 	height: 20px;
# 	_height: 27px;
# 	margin: 0 auto;
# 	padding-top: 7px;
# }
#
# .ly_inputko .btn_space {
# 	display: inline-block;
# 	width: 47px;
# 	height: 20px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -160px -40px;
# }
#
# .ly_inputko .btn_space button {
# 	width: 47px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_space_over {
# 	background-position: -160px -60px;
# }
#
# .ly_inputko .btn_del {
# 	display: inline-block;
# 	width: 39px;
# 	height: 20px;
# 	margin-left: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -220px -40px;
# }
#
# .ly_inputko .btn_del button {
# 	width: 39px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_del_over {
# 	background-position: -220px -60px;
# }
#
# .ly_inputko .btn_reset {
# 	display: inline-block;
# 	width: 39px;
# 	height: 20px;
# 	margin-left: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -260px -40px;
# }
#
# .ly_inputko .btn_reset button {
# 	width: 39px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_reset_over {
# 	background-position: -260px -60px;
# }
#
# .ly_inputko .number {
# 	overflow: hidden;
# 	float: left;
# 	_float: none;
# 	position: relative;
# 	width: 313px;
# 	height: 28px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -202px;
# }
#
# .ly_inputko .number .num {
# 	top: 1px;
# 	left: 1px;
# 	background-position: 0 -400px;
# }
#
# .ly_inputko .number .num2 {
# 	top: 1px;
# 	left: 27px;
# 	background-position: -40px -400px;
# }
#
# .ly_inputko .number .num3 {
# 	top: 1px;
# 	left: 53px;
# 	background-position: -80px -400px;
# }
#
# .ly_inputko .number .num4 {
# 	top: 1px;
# 	left: 79px;
# 	background-position: -120px -400px;
# }
#
# .ly_inputko .number .num5 {
# 	top: 1px;
# 	left: 105px;
# 	background-position: -160px -400px;
# }
#
# .ly_inputko .number .num6 {
# 	top: 1px;
# 	left: 131px;
# 	background-position: -200px -400px;
# }
#
# .ly_inputko .number .num7 {
# 	top: 1px;
# 	left: 157px;
# 	background-position: -240px -400px;
# }
#
# .ly_inputko .number .num8 {
# 	top: 1px;
# 	left: 183px;
# 	background-position: -280px -400px;
# }
#
# .ly_inputko .number .num9 {
# 	top: 1px;
# 	left: 209px;
# 	background-position: -320px -400px;
# }
#
# .ly_inputko .number .num0 {
# 	top: 1px;
# 	left: 235px;
# 	background-position: -360px -400px;
# }
#
# .ly_inputko .number .period {
# 	top: 1px;
# 	left: 261px;
# 	background-position: -400px -400px;
# }
#
# .ly_inputko .number .num_over {
# 	top: 0;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -240px;
# }
#
# .ly_inputko .number .num2_over {
# 	top: 0;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -240px;
# }
#
# .ly_inputko .number .num3_over {
# 	top: 0;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -240px;
# }
#
# .ly_inputko .number .num4_over {
# 	top: 0;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -240px;
# }
#
# .ly_inputko .number .num5_over {
# 	top: 0;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -240px;
# }
#
# .ly_inputko .number .num6_over {
# 	top: 0;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -240px;
# }
#
# .ly_inputko .number .num7_over {
# 	top: 0;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -240px;
# }
#
# .ly_inputko .number .num8_over {
# 	top: 0;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -240px;
# }
#
# .ly_inputko .number .num9_over {
# 	top: 0;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -240px;
# }
#
# .ly_inputko .number .num0_over {
# 	top: 0;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -240px;
# }
#
# .ly_inputko .number .period_over {
# 	top: 0;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -240px;
# }
#
# /* mouse korean */
# .ly_inputko .consonantal {
# 	float: left;
# 	position: relative;
# 	width: 181px;
# 	height: 79px;
# 	margin-bottom: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -120px;
# }
#
# .ly_inputko .vowel {
# 	position: absolute;
# 	top: 57px;
# 	left: 194px;
# 	width: 129px;
# 	height: 79px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat -184px -120px;
# }
#
# .ly_inputko .consonantal .con {
# 	top: 1px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -280px;
# }
#
# .ly_inputko .consonantal .con2 {
# 	top: 1px;
# 	left: 26px;
# 	background-position: -40px -280px;
# }
#
# .ly_inputko .consonantal .con3 {
# 	top: 1px;
# 	left: 52px;
# 	background-position: -80px -280px;
# }
#
# .ly_inputko .consonantal .con4 {
# 	top: 1px;
# 	left: 78px;
# 	background-position: -120px -280px;
# }
#
# .ly_inputko .consonantal .con5 {
# 	top: 1px;
# 	left: 104px;
# 	background-position: -160px -280px;
# }
#
# .ly_inputko .consonantal .con6 {
# 	top: 1px;
# 	left: 130px;
# 	background-position: -200px -280px;
# }
#
# .ly_inputko .consonantal .con7 {
# 	top: 1px;
# 	left: 156px;
# 	background-position: -240px -280px;
# }
#
# .ly_inputko .consonantal .con8 {
# 	top: 27px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -320px;
# }
#
# .ly_inputko .consonantal .con9 {
# 	top: 27px;
# 	left: 26px;
# 	background-position: -40px -320px;
# }
#
# .ly_inputko .consonantal .con10 {
# 	top: 27px;
# 	left: 52px;
# 	background-position: -80px -320px;
# }
#
# .ly_inputko .consonantal .con11 {
# 	top: 27px;
# 	left: 78px;
# 	background-position: -120px -320px;
# }
#
# .ly_inputko .consonantal .con12 {
# 	top: 27px;
# 	left: 104px;
# 	background-position: -160px -320px;
# }
#
# .ly_inputko .consonantal .con13 {
# 	top: 27px;
# 	left: 130px;
# 	background-position: -200px -320px;
# }
#
# .ly_inputko .consonantal .con14 {
# 	top: 27px;
# 	left: 156px;
# 	background-position: -240px -320px;
# }
#
# .ly_inputko .consonantal .con15 {
# 	top: 53px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -360px;
# }
#
# .ly_inputko .consonantal .con16 {
# 	top: 53px;
# 	left: 26px;
# 	background-position: -40px -360px;
# }
#
# .ly_inputko .consonantal .con17 {
# 	top: 53px;
# 	left: 52px;
# 	background-position: -80px -360px;
# }
#
# .ly_inputko .consonantal .con18 {
# 	top: 53px;
# 	left: 78px;
# 	background-position: -120px -360px;
# }
#
# .ly_inputko .consonantal .con19 {
# 	top: 53px;
# 	left: 104px;
# 	background-position: -160px -360px;
# }
#
# .ly_inputko .consonantal .con_over {
# 	top: 0;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -120px;
# }
#
# .ly_inputko .consonantal .con2_over {
# 	top: 0;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -120px;
# }
#
# .ly_inputko .consonantal .con3_over {
# 	top: 0;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -120px;
# }
#
# .ly_inputko .consonantal .con4_over {
# 	top: 0;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -120px;
# }
#
# .ly_inputko .consonantal .con5_over {
# 	top: 0;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -120px;
# }
#
# .ly_inputko .consonantal .con6_over {
# 	top: 0;
# 	left: 129px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -120px;
# }
#
# .ly_inputko .consonantal .con7_over {
# 	top: 0;
# 	left: 155px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -120px;
# }
#
# .ly_inputko .consonantal .con8_over {
# 	top: 26px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -160px;
# }
#
# .ly_inputko .consonantal .con9_over {
# 	top: 26px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -160px;
# }
#
# .ly_inputko .consonantal .con10_over {
# 	top: 26px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -160px;
# }
#
# .ly_inputko .consonantal .con11_over {
# 	top: 26px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -160px;
# }
#
# .ly_inputko .consonantal .con12_over {
# 	top: 26px;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -160px;
# }
#
# .ly_inputko .consonantal .con13_over {
# 	top: 26px;
# 	left: 129px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -160px;
# }
#
# .ly_inputko .consonantal .con14_over {
# 	top: 26px;
# 	left: 155px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -160px;
# }
#
# .ly_inputko .consonantal .con15_over {
# 	top: 52px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -200px;
# }
#
# .ly_inputko .consonantal .con16_over {
# 	top: 52px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -200px;
# }
#
# .ly_inputko .consonantal .con17_over {
# 	top: 52px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -200px;
# }
#
# .ly_inputko .consonantal .con18_over {
# 	top: 52px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -200px;
# }
#
# .ly_inputko .consonantal .con19_over {
# 	top: 52px;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -200px;
# }
#
# .ly_inputko .vowel .vow {
# 	top: 1px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -280px;
# }
#
# .ly_inputko .vowel .vow2 {
# 	top: 1px;
# 	left: 26px;
# 	background-position: -320px -280px;
# }
#
# .ly_inputko .vowel .vow3 {
# 	top: 1px;
# 	left: 52px;
# 	background-position: -360px -280px;
# }
#
# .ly_inputko .vowel .vow4 {
# 	top: 1px;
# 	left: 78px;
# 	background-position: -400px -280px;
# }
#
# .ly_inputko .vowel .vow5 {
# 	top: 1px;
# 	left: 104px;
# 	width: 24px;
# 	background-position: -440px -280px;
# }
#
# .ly_inputko .vowel .vow6 {
# 	top: 27px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -320px;
# }
#
# .ly_inputko .vowel .vow7 {
# 	top: 27px;
# 	left: 26px;
# 	background-position: -320px -320px;
# }
#
# .ly_inputko .vowel .vow8 {
# 	top: 27px;
# 	left: 52px;
# 	background-position: -360px -320px;
# }
#
# .ly_inputko .vowel .vow9 {
# 	top: 27px;
# 	left: 78px;
# 	background-position: -400px -320px;
# }
#
# .ly_inputko .vowel .vow10 {
# 	top: 27px;
# 	left: 104px;
# 	width: 24px;
# 	background-position: -440px -320px;
# }
#
# .ly_inputko .vowel .vow11 {
# 	top: 53px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -360px;
# }
#
# .ly_inputko .vowel .vow12 {
# 	top: 53px;
# 	left: 26px;
# 	background-position: -320px -360px;
# }
#
# .ly_inputko .vowel .vow13 {
# 	top: 53px;
# 	left: 52px;
# 	background-position: -360px -360px;
# }
#
# .ly_inputko .vowel .vow14 {
# 	top: 53px;
# 	left: 78px;
# 	background-position: -400px -360px;
# }
#
# .ly_inputko .vowel .vow_over {
# 	top: 0;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -120px;
# }
#
# .ly_inputko .vowel .vow2_over {
# 	top: 0;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -120px;
# }
#
# .ly_inputko .vowel .vow3_over {
# 	top: 0;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -120px;
# }
#
# .ly_inputko .vowel .vow4_over {
# 	top: 0;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -120px;
# }
#
# .ly_inputko .vowel .vow5_over {
# 	top: 0;
# 	left: 103px;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -440px -120px;
# }
#
# .ly_inputko .vowel .vow6_over {
# 	top: 26px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -160px;
# }
#
# .ly_inputko .vowel .vow7_over {
# 	top: 26px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -160px;
# }
#
# .ly_inputko .vowel .vow8_over {
# 	top: 26px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -160px;
# }
#
# .ly_inputko .vowel .vow9_over {
# 	top: 26px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -160px;
# }
#
# .ly_inputko .vowel .vow10_over {
# 	top: 26px;
# 	left: 103px;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -440px -160px;
# }
#
# .ly_inputko .vowel .vow11_over {
# 	top: 52px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -200px;
# }
#
# .ly_inputko .vowel .vow12_over {
# 	top: 52px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -200px;
# }
#
# .ly_inputko .vowel .vow13_over {
# 	top: 52px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -200px;
# }
#
# .ly_inputko .vowel .vow14_over {
# 	top: 52px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -200px;
# }
#
# .ly_inputko .consonantal .con button, .ly_inputko .consonantal .con8 button, .ly_inputko .consonantal .con15 button, .ly_inputko .vowel .vow button, .ly_inputko .vowel .vow5 button, .ly_inputko .vowel .vow6 button, .ly_inputko .vowel .vow10 button, .ly_inputko .vowel .vow11 button {
# 	width: 24px;
# }
#
# /* mouse english */
# .ly_inputko .alphabet {
# 	position: relative;
# 	width: 313px;
# 	height: 79px;
# 	margin-bottom: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -240px;
# }
#
# .ly_inputko .alphabet .alp {
# 	top: 1px;
# 	left: 1px;
# 	background-position: 0 -560px;
# }
#
# .ly_inputko .alphabet .alp2 {
# 	top: 1px;
# 	left: 27px;
# 	background-position: -40px -560px;
# }
#
# .ly_inputko .alphabet .alp3 {
# 	top: 1px;
# 	left: 53px;
# 	background-position: -80px -560px;
# }
#
# .ly_inputko .alphabet .alp4 {
# 	top: 1px;
# 	left: 79px;
# 	background-position: -120px -560px;
# }
#
# .ly_inputko .alphabet .alp5 {
# 	top: 1px;
# 	left: 105px;
# 	background-position: -160px -560px;
# }
#
# .ly_inputko .alphabet .alp6 {
# 	top: 1px;
# 	left: 131px;
# 	background-position: -200px -560px;
# }
#
# .ly_inputko .alphabet .alp7 {
# 	top: 1px;
# 	left: 157px;
# 	background-position: -240px -560px;
# }
#
# .ly_inputko .alphabet .alp8 {
# 	top: 1px;
# 	left: 183px;
# 	background-position: -280px -560px;
# }
#
# .ly_inputko .alphabet .alp9 {
# 	top: 1px;
# 	left: 209px;
# 	background-position: -320px -560px;
# }
#
# .ly_inputko .alphabet .alp10 {
# 	top: 1px;
# 	left: 235px;
# 	background-position: -360px -560px;
# }
#
# .ly_inputko .alphabet .alp11 {
# 	top: 1px;
# 	left: 261px;
# 	background-position: -400px -560px;
# }
#
# .ly_inputko .alphabet .alp12 {
# 	top: 1px;
# 	left: 287px;
# 	background-position: -440px -560px;
# }
#
# .ly_inputko .alphabet .alp13 {
# 	top: 27px;
# 	left: 1px;
# 	background-position: 0 -600px;
# }
#
# .ly_inputko .alphabet .alp14 {
# 	top: 27px;
# 	left: 27px;
# 	background-position: -40px -600px;
# }
#
# .ly_inputko .alphabet .alp15 {
# 	top: 27px;
# 	left: 53px;
# 	background-position: -80px -600px;
# }
#
# .ly_inputko .alphabet .alp16 {
# 	top: 27px;
# 	left: 79px;
# 	background-position: -120px -600px;
# }
#
# .ly_inputko .alphabet .alp17 {
# 	top: 27px;
# 	left: 105px;
# 	background-position: -160px -600px;
# }
#
# .ly_inputko .alphabet .alp18 {
# 	top: 27px;
# 	left: 131px;
# 	background-position: -200px -600px;
# }
#
# .ly_inputko .alphabet .alp19 {
# 	top: 27px;
# 	left: 157px;
# 	background-position: -240px -600px;
# }
#
# .ly_inputko .alphabet .alp20 {
# 	top: 27px;
# 	left: 183px;
# 	background-position: -280px -600px;
# }
#
# .ly_inputko .alphabet .alp21 {
# 	top: 27px;
# 	left: 209px;
# 	background-position: -320px -600px;
# }
#
# .ly_inputko .alphabet .alp22 {
# 	top: 27px;
# 	left: 235px;
# 	background-position: -360px -600px;
# }
#
# .ly_inputko .alphabet .alp23 {
# 	top: 27px;
# 	left: 261px;
# 	background-position: -400px -600px;
# }
#
# .ly_inputko .alphabet .alp24 {
# 	top: 27px;
# 	left: 287px;
# 	background-position: -440px -600px;
# }
#
# .ly_inputko .alphabet .alp25 {
# 	top: 53px;
# 	left: 1px;
# 	background-position: 0 -640px;
# }
#
# .ly_inputko .alphabet .alp26 {
# 	top: 53px;
# 	left: 27px;
# 	background-position: -40px -640px;
# }
#
# .ly_inputko .alphabet .alp_over {
# 	top: 0;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -440px;
# }
#
# .ly_inputko .alphabet .alp2_over {
# 	top: 0;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -440px;
# }
#
# .ly_inputko .alphabet .alp3_over {
# 	top: 0;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -440px;
# }
#
# .ly_inputko .alphabet .alp4_over {
# 	top: 0;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -440px;
# }
#
# .ly_inputko .alphabet .alp5_over {
# 	top: 0;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -440px;
# }
#
# .ly_inputko .alphabet .alp6_over {
# 	top: 0;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -440px;
# }
#
# .ly_inputko .alphabet .alp7_over {
# 	top: 0;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -440px;
# }
#
# .ly_inputko .alphabet .alp8_over {
# 	top: 0;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -440px;
# }
#
# .ly_inputko .alphabet .alp9_over {
# 	top: 0;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -440px;
# }
#
# .ly_inputko .alphabet .alp10_over {
# 	top: 0;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -440px;
# }
#
# .ly_inputko .alphabet .alp11_over {
# 	top: 0;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -440px;
# }
#
# .ly_inputko .alphabet .alp12_over {
# 	top: 0;
# 	left: 286px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -440px -440px;
# }
#
# .ly_inputko .alphabet .alp13_over {
# 	top: 26px;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -480px;
# }
#
# .ly_inputko .alphabet .alp14_over {
# 	top: 26px;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -480px;
# }
#
# .ly_inputko .alphabet .alp15_over {
# 	top: 26px;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -480px;
# }
#
# .ly_inputko .alphabet .alp16_over {
# 	top: 26px;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -480px;
# }
#
# .ly_inputko .alphabet .alp17_over {
# 	top: 26px;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -480px;
# }
#
# .ly_inputko .alphabet .alp18_over {
# 	top: 26px;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -480px;
# }
#
# .ly_inputko .alphabet .alp19_over {
# 	top: 26px;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -480px;
# }
#
# .ly_inputko .alphabet .alp20_over {
# 	top: 26px;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -480px;
# }
#
# .ly_inputko .alphabet .alp21_over {
# 	top: 26px;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -480px;
# }
#
# .ly_inputko .alphabet .alp22_over {
# 	top: 26px;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -480px;
# }
#
# .ly_inputko .alphabet .alp23_over {
# 	top: 26px;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -480px;
# }
#
# .ly_inputko .alphabet .alp24_over {
# 	top: 26px;
# 	left: 286px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -440px -480px;
# }
#
# .ly_inputko .alphabet .alp25_over {
# 	top: 52px;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -520px;
# }
#
# .ly_inputko .alphabet .alp26_over {
# 	top: 52px;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -520px;
# }
#
# /*# sourceMappingURL=api_setkr_https.css.map */
# /*# sourceMappingURL=data:application/json;base64,... */</style><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/tveta/libs/assets/css/pc/main/min/main_topic_darkmode.min.css?20200601"></head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap"> <style type="text/css">._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;width:18px;height:18px;margin:16px 8px 0 0;background-position:0 -89px}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._1syGnXOL._3dsvmZg2:before{background-position:-68px -63px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-26px -85px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-26px -63px}._1syGnXOL._18YOHi7v{color:#fff}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL._3jtl_dKE{font-size:16px}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-98px -30px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px 0;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -15px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-48px -83px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.05)}</style>
# <div id="NM_TOP_BANNER" data-clk-prefix="top" class="_1hiMWemA" style="background-color: #3c3f48;">
# <div class="tY_u8r23">
# <a class="_3h-N8T9V" href="https://whale.naver.com/details/darkmode?=main&amp;wpid=RydDy7" data-clk="dropbanner1b"></a>
# <i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i>
# <img src="https://static-whale.pstatic.net/main/img_darkmode_v2@2x.png" width="303" height="49" alt="" style="padding-left: 34px;">
# <span class="_1syGnXOL _18YOHi7v _3jtl_dKE _3di88A4c" data-clk="dropbanner1b" style="padding-right: 10px; padding-left: 12px;">
# <span>여러분의 눈은 소중하니까, </span><strong>웹 페이지까지 다크하게!</strong></span>
# <a href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" class="_2aeXMlrb BMgpjddw" id="NM_whale_download_btn" data-clk="dropdownload1b"><span style="background-color: #875af1;">다운로드</span></a>
# <button type="button" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" data-clk="dropclose1b" class="_20PYt6lT _3wm5EzmJ" style="">3일 동안 보지 않기
# </button>
# </div>
# </div>  <div id="header" role="banner">
#
#
#
#
#
#
#
#
#
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_special">
# <img src="https://s.pstatic.net/static/www/mobile/edit/2020/1218/mobile_10541380168.png" width="415" height="160" class="special_img" alt="애동지">
# <a href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_brd&amp;fbm=1&amp;ie=utf8&amp;query=2020%EB%85%84+%EC%95%A0%EB%8F%99%EC%A7%80" class="special_logo_link" title="애동지" data-clk="top.spe">
# <img src="https://s.pstatic.net/static/www/mobile/edit/2020/1218/mobile_105421218867.png" width="58" height="60" class="special_img_fold" alt="애동지">
# </a>
# </h1>
# </div>
# <div class="service_area">
# <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
#
# <div id="search" class="search_area" data-clk-prefix="sch">
# <form id="sform" name="sform" action="https://search.naver.com/search.naver" method="get" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select id="where" name="where" title="검색 범위 선택" class="blind">
# <option value="nexearch" selected="selected">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input type="hidden" id="sm" name="sm" value="top_hty">
# <input type="hidden" id="fbm" name="fbm" value="0">
# <input type="hidden" id="acr" name="acr" value="" disabled="disabled">
# <input type="hidden" id="acq" name="acq" value="" disabled="disabled">
# <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled">
# <input type="hidden" id="ie" name="ie" value="utf8">
# <input type="hidden" id="acir" name="acir" value="" disabled="disabled">
# <input type="hidden" id="os" name="os" value="" disabled="disabled">
# <input type="hidden" id="bid" name="bid" value="" disabled="disabled">
# <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled">
# <input type="hidden" id="eid" name="eid" value="" disabled="disabled">
# <input type="hidden" id="mra" name="mra" value="" disabled="disabled">
#
#
#
#
#
#
# <div class="green_window window_focus" style="border-color: #cfad97;">
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off" placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element="">
# </div>
# <button id="search_btn" type="submit" title="검색" tabindex="3" class="btn_submit" onclick="window.nclick(this,'sch.action','','',event);" style="background-color: #cfad97">
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="return false;"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a href="#" role="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" aria-pressed="false" data-atcmp-element=""><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div id="autoFrame" class="reatcmp" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element="">
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a href="#" role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _keywordOnOff">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
#
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <i class="imsc ico_election"></i>
# <p class="dsc">선거 후보자에 대해 자동완성을 제공하지 않습니다.
# <span class="dsc_inner">기간 : 4월 2일 0시 ~ 4월 15일 18시까지</span>
# <a href="#" class="link">자세히보기</a>
# </p>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" class="link_dsc" data-clk="sug.cxhelp" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a role="button" href="#" class="bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a href="https://help.naver.com/support/contents/contents.help?serviceNo=606&amp;categoryNo=16659" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a href="https://nid.naver.com/nidlogin.login" class="btn btn_login" data-clk="sug.cxlogin">로그인</a>
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a href="#" role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1987" data-clk="sug.help" target="_blank">도움말</a></span>
# <span class="opt_item"><a href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" class="report" data-clk="sug.report" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _suggestOnOff">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--EMPTY-->
# <div id="gnb">
# <div id="NM_FAVORITE" class="gnb_inner">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
# <li class="nav_item"><a href="https://shopping.naver.com/" class="nav" data-clk="svc.shopping">쇼핑</a></li>
# <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>
# <li class="nav_item">
# <a href="https://tv.naver.com/" class="nav" data-clk="svc.tvcast"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul class="list_nav NM_FAVORITE_LIST">
# <li class="nav_item"><a href="https://dict.naver.com/" class="nav" data-clk="svc.dic">사전</a></li>
# <li class="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.news">뉴스</a></li>
# <li class="nav_item"><a href="https://finance.naver.com/" class="nav" data-clk="svc.stock">증권</a></li>
# ...
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30240196&amp;memberNo=15627980" class="theme_info" data-clk="tcc_ani.list11cont3" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">경찰이 보는 앞에서 발코니 너머로 개 던진 여자😨</strong>
# 						<p class="desc">[노트펫 김승연 기자] 견주에 의해 발코니서 던져진 개는 기적적으로 살아남아 '미라클(Miracle)'이라는 이름을 얻게 됐다. 지난 15일(현지 시각) 미국 연예 매체 TMZ는 미국에서 한 견주가 자살 시도 전 발코니에서 반려견을 집어 던진 혐의로 체포됐다고 보도했다.최근 미국 플로리다주 볼루시아 카운티 경찰은 자살 시도를 하</p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source"><span class="source_inner">노트펫</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_73603a2e-4041-11eb-aece-45a426cd318b" data-da-position="true">
# 					<a href="https://blog.naver.com/animalkara/222174467790" class="theme_thumb" data-clk="tcc_ani.list11cont4" target="_blank">
# 						<img alt="시골의 한 창고에서 태어난 '알콩' &amp; '달콩'" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_24209587296759524wTSj8.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/animalkara/222174467790" class="theme_info" data-clk="tcc_ani.list11cont4" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">시골의 한 창고에서 태어난 '알콩' &amp; '달콩'</strong>
# 						<p class="desc">단체에서 구조한 동물들 외에도 개인이 구조하여 보호하고 있는 유기동물들도 가족을 기다리고 있습니다. 개인구조의 입양절차와 신청은 단체의 기준과 다릅니다. 게시글 내의 구조자와 직접 상담하여 입양을 결정하시면 됩니다.구조자 정보: 이유정 / 010-7744-8887구조 일시 및 장소: 2020.11.2 / 서울시 강서구구조 동물 정보: 고양이 / 암컷 / 3</p>
# 						<div class="source_box">
# 							<span class="date">6일 전</span>
# 							<span class="source"><span class="source_inner">동물권행동 카라</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_ce0c2ccc-4039-11eb-a2b1-e5cfb32b8f9f" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30229600&amp;memberNo=37963193" class="theme_thumb" data-clk="tcc_ani.list11cont5" target="_blank">
# 						<img alt="자존심 대결! 박진감 넘치는 토끼 점프 대회" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_24208798404837745mFNIt.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30229600&amp;memberNo=37963193" class="theme_info" data-clk="tcc_ani.list11cont5" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">자존심 대결! 박진감 넘치는 토끼 점프 대회</strong>
# 						<p class="desc">동물들을 위한 이색대회가 세계 곳곳에서 열리는 가운데 가장 귀여운 스포츠 선수로 토끼가 주목받았습니다. 지난 12일, 해외 매체 유니래드(UNILAD)는 이제까지 스포츠 중에 가장 귀여운 스포츠로 토끼쇼 점프(Rabbit Show Jumping)를 선정했습니다. 말이나 개가 출전하는 전문대회는 잘 알려졌지만, 토끼 대회는 국내에</p>
# 						<div class="source_box">
# 							<span class="date">6일 전</span>
# 							<span class="source"><span class="source_inner">팸타임스</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
# <div class="group_theme" data-block-id="" data-block-code="PC-THEME-ANIMAL-MOBILE-RANKING-DEFAULT-11" data-block-type="MATERIALS" data-template-code="MOBILE-RANKING-LIST" data-da="container" data-index="" data-page="6" style="display:none">
#
# 	<div class="list_theme_wrap">
# 		<ul class="list_theme">
#
# 				<li class="theme_item" data-gdid="CAS_73603a2b-4041-11eb-aece-11e1c4d375c5" data-da-position="true">
# 					<a href="https://blog.naver.com/ghktnskfk12/222174484663" class="theme_thumb" data-clk="tcc_ani.list12cont1" target="_blank">
# 						<img alt="실물 깡패! 까만 조랭이떡이 엄빠를 찾아요" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_24209554043876854D4qoT.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/ghktnskfk12/222174484663" class="theme_info" data-clk="tcc_ani.list12cont1" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">실물 깡패! 까만 조랭이떡이 엄빠를 찾아요</strong>
# 						<p class="desc">#대구유기견 #경산유기견​💕조랭이 떡 같은 까망이가 요러고 있어요💕​까망이는 실물이 훨씬 더 이쁜거 아시죠~?!!말도 못해요 ㅠㅠ 진짜진짜 귀여워용..​이제 3개월 반 정도로, 공주님 이에요!!똥실똥실 해가지곤 진짜 귀여워용 ㅠㅠ​​01095950628 문의는 '아이사진 또는 공고번호 함께 문자' 남겨주세요. 전화 잘 못받아요 ​입양시 '중성화 시행'.</p>
# 						<div class="source_box">
# 							<span class="date">6일 전</span>
# 							<span class="source"><span class="source_inner">사랑이엄마</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_320f9aa8-4040-11eb-aece-4bc10e0575f9" data-da-position="true">
# 					<a href="https://blog.naver.com/animalandhuman/222176360381" class="theme_thumb" data-clk="tcc_ani.list12cont2" target="_blank">
# 						<img alt="'엉따' 좋다옹😻 냥이의 비데 집착은 어디까지" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_242106854312669658XuTX.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/animalandhuman/222176360381" class="theme_info" data-clk="tcc_ani.list12cont2" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">'엉따' 좋다옹😻 냥이의 비데 집착은 어디까지</strong>
# 						<p class="desc">날이 정말 추워졌어요. 개집사인 저는 산책을 하다가도 손이 새빨갛게 어는 게 느껴져 계속 왼손 오른손 번갈아가며 리드줄을 잡곤 한답니다. 리드줄이 잡는 게 힘들어지면 ‘아, 겨울이 왔구나~’ 싶죠. 다른 반려인 분들은 어떨 때 겨울이 왔다는 걸 느끼시는지 모르겠네요.​오늘은 겨울만 왔다 하면 특이 행동을 보이는 한 고양이를 소개해드리려고 합니다. 이름은 간</p>
# 						<div class="source_box">
# 							<span class="date">4일 전</span>
# 							<span class="source"><span class="source_inner">동그람이</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_320f9aab-4040-11eb-aece-115f3b75202b" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30241907&amp;memberNo=46511596" class="theme_thumb" data-clk="tcc_ani.list12cont3" target="_blank">
# 						<img alt="꽃사슴이 매일 현충원에 출석 도장 찍는 사연" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_24211030880076003gYCfJ.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30241907&amp;memberNo=46511596" class="theme_info" data-clk="tcc_ani.list12cont3" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">꽃사슴이 매일 현충원에 출석 도장 찍는 사연</strong>
# 						<p class="desc">현충원 묘지 사이로 돌아다니는 꽃사슴들지난 14일 KBS 유튜브 채널 '애니멀포유'는 국립대전현충원에 나타나는 꽃사슴들의 모습을 공개했다. 영상 속 꽃사슴들은 현충원에 있는 묘지 사이를 자유롭게 돌아다니고 있었다. 꽃사슴들은 묘지에 놓인 꽃의 냄새를 맡고 풀을 뜯어 먹는 모습을 보였다. 이를 본 누리꾼들은 '나도 목격했는데 눈이 참 맑고 예쁘더라', '현충</p>
# 						<div class="source_box">
# 							<span class="date">4일 전</span>
# 							<span class="source"><span class="source_inner">더패치</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_320f9aa9-4040-11eb-aece-a7a407b6660a" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30243411&amp;memberNo=52065613" class="theme_thumb" data-clk="tcc_ani.list12cont4" target="_blank">
# 						<img alt="웰시코기 교배 금지한 '코기 덕후' 여왕의 사정" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_24210748875590634on87P.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.nhn?volumeNo=30243411&amp;memberNo=52065613" class="theme_info" data-clk="tcc_ani.list12cont4" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">웰시코기 교배 금지한 '코기 덕후' 여왕의 사정</strong>
# 						<p class="desc">영국 여왕인 엘리자베스 2세는 옛날부터 반려동물을 사랑하기로 유명했습니다. 하지만 최근 엘리자배스의 애견 중 한 마리인 '벌칸' 이 죽었다고 NBC 뉴스가 전했습니다. 이제 영국 여왕이 키우던 4마리의 반려견중 단 한 마리 '캔디'만 버킹엄 궁전을 지킨다고 하네요.여왕은 다른 견종들 중 웰시코기를 가장 좋아한다고 알려졌으며 보도에 따르면 엘리자베스 2세는 </p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source"><span class="source_inner">펫투게더</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_320f9aae-4040-11eb-aece-255739039e1a" data-da-position="true">
# 					<a href="https://blog.naver.com/jackkay/222175969771" class="theme_thumb" data-clk="tcc_ani.list12cont5" target="_blank">
# 						<img alt="캠핑장 떠돌며 남은 밥 얻어 먹던 '순심이'" width="170" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1218%2Fupload_242096169797924590opSl.jpg%22&amp;type=nf340_228" loading="lazy">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/jackkay/222175969771" class="theme_info" data-clk="tcc_ani.list12cont5" target="_blank">
# 						<em class="theme_category"> 동물공감</em>
# 						<strong class="title elss">캠핑장 떠돌며 남은 밥 얻어 먹던 '순심이'</strong>
# 						<p class="desc">#유기견입양 #진돗개분양 #진도믹스 #순심이 #사지말고입양하세요​​너무 순해서다른 개들한테 물리는 아이에요간식을 줘도 달라들지않고 기다릴줄 알고요.순심이 오늘 중성화수술하고 회복중에 있어요캠핑장에서 밥 얻어먹던 아이...​이렇게 순하고 차분한 아이는기질 자체가 얌전해서 어디든 함께 다녀도잘 따라와줄 거에요​눈에서 선함이 느껴지는 우리 순심이..계속 눈에 .</p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source"><span class="source_inner">소녀만물상</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
#
#
# 	<p class="alert_msg" data-clk-prefix="tcc_ani">동물공감판의 컨텐츠는 <a href="https://blog.naver.com/animalandhuman/221081025234" data-clk-suffix="corp" target="_blank">㈜동그람이</a>에 의해 운영·편집 됩니다.</p>
#
#
#
# 	<div class="btn_more_wrap">
# 		<button type="button" class="btn_more" data-clk-custom="tcc_ani.more" data-next-page="2"><i class="ico_more"></i>새로운 글 더보기</button>
# 	</div>
#
#
# 	</div>
# </div>
#  </div> </div> <div id="NM_INT_RIGHT" class="column_right"> <div class="column_fix_wrap"> <div id="da_brand"></div>
#
#
#
#
# <div id="account" class="sc_login">
# <h2 class="blind">로그인</h2>
# <p class="login_msg">네이버를 더 안전하고 편리하게 이용하세요</p>
# <a href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">네이버</span></i>로그인</a>
# <div class="sub_area">
# <div class="look_box">
# <a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="link_look" data-clk="log_off.searchid">아이디</a>
# <a href="https://nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchpass">비밀번호찾기</a>
# </div>
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.registration">회원가입</a>
# </div>
# </div>
#
#
#
#  <div id="timesquare" class="sc_timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a href="#" role="button" class="btn_nav btn_prev" data-clk="squ.pre"><span class="blind">이전</span></a>
# <a href="#" role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;" data-nm-ui="rolling">
#
#
#
#
#
#
#
#
#
# <div class="eg-flick-viewport" style="position: relative; z-index: 0; overflow: hidden; min-height: 100%; width: 100%; touch-action: pan-y; user-select: none; -webkit-user-drag: none; height: 47px;"><div class="eg-flick-camera" style="width: 100%; height: 100%; will-change: transform; transform: translate3d(0px, 0px, 0px);"><div style="width: 281px; position: absolute; left: 0px;" class="eg-flick-panel">
# <a href="https://news.naver.com/main/home.nhn" class="card_news" data-clk="squ.line1"><i class="news_badge type_live">LIVE</i><span class="news">저녁방송 메인뉴스 보기</span></a>
# </div></div></div></div>
# </div> <!-- EMPTY --> </div>  <div id="veta_branding"> <iframe id="da_iframe_rolling" name="da_iframe_rolling" data-veta-preview="main_rolling" title="광고" width="350" height="200" marginheight="0" marginwidth="0" scrolling="no" frameborder="0" src="https://siape.veta.naver.com/fxshow?su=SU10601&amp;nrefreshx=0"></iframe> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div>   <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" title="쇼핑캐스트" width="350" height="1539" marginheight="0" marginwidth="0" scrolling="no" frameborder="0" src="https://castbox.shopping.naver.com/shoppingboxnew/main.nhn"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wrap" class="content_top"><span class="blind">TOP</span></a> <button id="NM_darkmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false"> <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div class="banner_area"> <div class="da_box_wrap">    <div id="da_public_left"> <iframe id="da_iframe_bottom_left" title="광고" width="350" height="86" scrolling="no" frameborder="0" src="https://siape.veta.naver.com/fxshow?su=SU10641&amp;nrefreshx=0"></iframe> </div> <div id="da_public_right"> <iframe id="da_iframe_bottom_right" title="광고" width="350" height="86" scrolling="no" frameborder="0" src="https://siape.veta.naver.com/fxshow?su=SU10642&amp;nrefreshx=0"></iframe> </div> <div id="veta_time2"> <iframe id="da_iframe_below" name="da_iframe_below" data-veta-preview="main_below" width="350" height="86" scrolling="no" frameborder="0" title="광고" src="https://siape.veta.naver.com/fxshow?su=SU10640&amp;nrefreshx=0"> </iframe> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3> <!-- EMPTY --> </div> <a href="more.html" class="link_all" data-clk="svcmap">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a href="https://www.navercorp.com/service/creators" class="link_partner" data-clk="creator">크리에이터</a> <a href="https://www.navercorp.com/service/business" class="link_partner" data-clk="smbusiness">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="https://business.naver.com/service.html" class="link_partner" data-clk="service">비즈니스 · 광고</a> <a href="https://sell.storefarm.naver.com/#/home/about" class="link_partner" data-clk="store">스토어 개설</a> <a href="https://smartplace.naver.com" class="link_partner" data-clk="place">지역업체 등록</a> <a href="https://expert.naver.com/?tab=guide#join" class="link_partner" data-clk="expert">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="https://developers.naver.com" class="link_partner" data-clk="center">네이버 개발자 센터</a> <a href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi">오픈 API</a> <a href="https://naver.github.io" class="link_partner" data-clk="opensource">오픈소스</a> <a href="https://d2.naver.com" class="link_partner" data-clk="d2">네이버 D2</a> <a href="http://d2startup.com" class="link_partner" data-clk="naverD2SF">네이버 D2SF</a> <a href="https://www.naverlabs.com" class="link_partner" data-clk="labs">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.com/" class="service_logo" data-clk="bt"> <img src="data:image/png;base64,..." alt="웨일" width="48" height="48"> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a href="http://whale.naver.com/" class="dsc" data-clk="bt">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a href="https://search.naver.com/search.naver?where= ...
# </body></html>

# %%
ageList = {'1': '10s', '2': '20s', '3': '30s', '4': '40s', '5': '50s', '6': 'all'}
url1 = 'https://datalab.naver.com/keyword/realtimeList.naver?age='
url2 = '&entertainment=0&groupingLevel=2&marketing=0&news=0&sports=0&where=main'

# %%
key = input('연령대를 입력하세요(1 => 10대, 2 => 20대, 3 => 30대, 4 => 40대, 5 => 50대, 6 => 전체) : ')
targetSite = '{}{}{}'.format(url1, ageList[key], url2)

driver = webdriver.Chrome('./chromedriver.exe')
driver.get(targetSite)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

titles = soup.findAll('span', {'class': 'item_title'})
for i in range(len(titles)):
    print('{0:2d}위 : {1}'.format(i + 1, titles[i].text))
# Out:
# 연령대를 입력하세요(1 => 10대, 2 => 20대, 3 => 30대, 4 => 40대, 5 => 50대, 6 => 전체) : 2
#  1위 : 정일훈
#  2위 : 정일훈 마약
#  3위 : 5인이상 집합금지
#  4위 : 김포골드라인
#  5위 : 케스파컵
#  6위 : 애동지
#  7위 : 쌍용차
#  8위 : 큐브엔터테인먼트
#  9위 : 생활의달인 김치달인
# 10위 : 실족사
# 11위 : 생활의달인 평양냉면
# 12위 : 지하철
# 13위 : 무엇이든 물어보살
# 14위 : 목성 토성
# 15위 : 골든일레븐
# 16위 : 아리아나 그란데
# 17위 : 김포
# 18위 : 구하라
# 19위 : 김원효 심진화 김밥
# 20위 : 체스카
