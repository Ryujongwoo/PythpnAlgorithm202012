# %%
from IPython.display import Image
Image('./insertionSort.png', width = '1300')
# insertion Sort는 이미 정렬된 파일에 새로운 데이터를 위치에 맞게 삽입한다.

# %%
for i in range(1, 5):
    for j in range(i - 1, -1, -1):
        print('i = {}, j = {}'.format(i, j))
# Out:
# i = 1, j = 0
# i = 2, j = 1
# i = 2, j = 0
# i = 3, j = 2
# i = 3, j = 1
# i = 3, j = 0
# i = 4, j = 3
# i = 4, j = 2
# i = 4, j = 1
# i = 4, j = 0

# %%
sortData = [8, 3, 4, 9, 1]
for i in range(1, len(sortData)): # 새 데이터의 위치
    # 이미 정렬된 파일에 새 데이터가 삽입될 위치를 찾기 위해 새 데이터와 인덱스를 각각 key와 index에 저장한다.
    key = sortData[i]
    index = i
    # 새 데이터가 삽입될 위치를 찾는다.
    for j in range(i - 1, -1, -1):
        if sortData[j] > key:
            # 정렬된 파일의 데이터가 크기 때문에 정렬된 파일 데이터를 인덱스가 1큰 위치로 이동시키고 삽입할 데이터의 인덱스를
            # 1감소 시킨다.
            sortData[j + 1] = sortData[j]
            index -= 1
        else:
            # 삽입될 데이터가 이미 정렬된 파일의 데이터와 같거나 더 크다는 의미이므로 이미 정렬된 데이터 앞의 데이터와 더 이상
            # 비교할 필요가 없으므로 반복할 필요가 없어진다. => 반복을 탈출시킨다.
            break;
        # ===== if
    # ===== for j => 회전 끝
    # 새 데이터를 정렬된 파일의 위치에 맞게 삽입한다.
    sortData[index] = key
    print('{} 회전 결과 : {}'.format(i, sortData))
# ===== for i => 정렬 끝
# print('정렬 결과 : {}'.format(sortData))
# Out:
# 1 회전 결과 : [3, 8, 4, 9, 1]
# 2 회전 결과 : [3, 4, 8, 9, 1]
# 3 회전 결과 : [3, 4, 8, 9, 1]
# 4 회전 결과 : [1, 3, 4, 8, 9]
